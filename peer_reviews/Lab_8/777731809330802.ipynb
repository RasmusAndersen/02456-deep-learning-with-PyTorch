# %% [markdown]
# # Solve cartpole with REINFORCE
#
# > By Jonas Busk ([jbusk@dtu.dk](mailto:jbusk@dtu.dk))
#
# **2019 update:** Changes have been made to the display of environments due to the previous `viewer` being incompatible with newer versions of Gym.
#
# In this part, we will create an agent that can learn to solve the [cartpole problem](https://gym.openai.com/envs/CartPole-v0/) from OpenAI Gym by applying a simple policy gradient method called REINFORCE.
# In the cartpole problem, we need to balance a pole on a cart that moves along a track by applying left and right forces to the cart.
#
# We will implement a probabilistic policy, that given a state of the environment, $s$, outputs a probability distribution over available actions, $a$:
#
# $$
# p_\theta(a|s)
# $$
#
# The policy is a neural network with parameters $\theta$ that can be trained with gradient descent.
# When the set of available actions is discrete, we can use a network with softmax output do describe the distribution.
# The core idea of training the policy network is quite simple: *we want to maximize the expected total reward by increasing the probability of good actions and decreasing the probability of bad actions*.
#
# To achieve this, we apply the gradient of the expected discounted total reward (return):
#
# $$
# \begin{align}
# \nabla_\theta \mathbb{E}[R|\theta] &= \nabla_\theta \int p_\theta(a|s) R({a}) \, da \\
# &= \int \nabla_\theta p_\theta(a|s) R(a)  \, da \\
# &= \int p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) R(a) \, da \\
# &= \mathbb{E}[\nabla_\theta \log p_\theta(a|s) R(a)]
# \end{align}
# $$
#
# by definition of expectation and using the identity
#
# $$
# \nabla_\theta p_\theta(a|s) = p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) \ .
# $$
#
# The expectation cannot be evaluated analytically, but we have an environment simulator that when supplied with our current policy $p_\theta(a|s)$ can return a sequence of *actions*, *states* and *rewards*. This allows us to replace the integral with a Monte Carlo average:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) R_t \ ,
# $$
#
# which is our final gradient estimator, also known as REINFORCE. In the Monte Carlo estimator we run the environment simulator for a predefined number of steps with actions chosen stochastically according to the current stochastic action network $p_\theta(a|s)$.

# %% [markdown]
# *Note: For simple reinforcement learning problems (like the one we will address in this exercise) there are simpler methods that work just fine. However, the Policy Gradient method (with some extensions) has been shown to also work well for complex problems with high dimensional inputs and many parameters, where simple methods become inadequate.*

# %% [markdown]
# ## Policy gradient

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gym
from gym import wrappers

# %% [markdown]
# First we create the environment:

# %%
env = gym.make('CartPole-v0') # Create environment

# %% [markdown]
# A state in this environment is four numbers describing the position of the cart along with the angle and speed of the pole.
# There are two available actions: push the cart *left* or *right* encoded as 0 and 1.

# %%
s = env.reset()
a = env.action_space.sample()
print('sample state:', s)
print('sample action:', a )
# Out:
# sample state: [-0.03698918  0.0400388   0.01094685  0.04826156]
# sample action: 1

# %% [markdown]
# **Note:** you will likely not be able to render environments in a Google Colab instance. Therefore, it may be beneficial for you to run this week's notebooks locally and/or team up with another student if you do not have a local environment.
#
# The function below is used for display:

# %%
def show_replay():
    """
    Not-so-elegant way to display the MP4 file generated by the Monitor wrapper inside a notebook.
    The Monitor wrapper dumps the replay to a local file that we then display as a HTML video object.
    """
    import io
    import base64
    from IPython.display import HTML
    video = io.open('./gym-results/openaigym.video.%s.video000000.mp4' % env.file_infix, 'r+b').read()
    encoded = base64.b64encode(video)
    return HTML(data='''
        <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''
    .format(encoded.decode('ascii')))

# %% [markdown]
# Let us see how the environment looks when we just take random actions. Note that the episode ends when the pole either 1) is more than 15 degrees from vertical, 2) more outside of the frame or 3) the pole is successfully balanced for some fixed duration.

# %%
env = gym.make('CartPole-v0') # Create environment
env = wrappers.Monitor(env, "./gym-results", force=True) # Create wrapper to display environment
env.reset() # Reset environment

# Run environment
while True:
    env.render() # Render environment
    action = env.action_space.sample() # Get a random action
    _, _, done, _ = env.step(action) # Take a step
    if done: break # Break if environment is done

env.close() # Close environment
show_replay()
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# Taking random actions does not do a very good job at balancing the pole. Let us now apply the Policy Gradient method described above to solve this task!
#
# Let's first define our network and helper functions.

# %%
class PolicyNet(nn.Module):
    """Policy network"""

    def __init__(self, n_inputs, n_hidden, n_outputs, learning_rate):
        super(PolicyNet, self).__init__()
        # network
        self.hidden = nn.Linear(n_inputs, 20)
#         self.hidden2 = nn.Linear(50,30)
#         self.hidden3 = nn.Linear(30,n_hidden)
        self.out = nn.Linear(n_hidden, n_outputs)
        # training
        self.activation = torch.nn.ReLU()
        
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = self.activation(self.hidden(x))
#         x = self.activation(self.hidden2(x))
#         x= self.activation(self.hidden3(x))
        x = self.out(x)
        return F.softmax(x, dim=1)
    
    def loss(self, action_probabilities, returns):
        return -torch.mean(torch.mul(torch.log(action_probabilities), returns))

# %%
def compute_returns(rewards, discount_factor):
    """Compute discounted returns."""
    returns = np.zeros(len(rewards))
    returns[-1] = rewards[-1]
    for t in reversed(range(len(rewards)-1)):
        returns[t] = rewards[t] + discount_factor * returns[t+1]
    return returns

# %% [markdown]
# To start with, our policy will be a rather simple neural network with one hidden layer. We can retrieve the shape of the state space (input) and action space (output) from the environment.

# %%
n_inputs = env.observation_space.shape[0]
n_hidden = 20
n_outputs = env.action_space.n

print('state shape:', n_inputs)
print('action shape:', n_outputs)
# Out:
# state shape: 4
# action shape: 2

# %%
# training settings

num_episodes = 10000
rollout_limit = 500 # max rollout length
discount_factor = 1 # reward discount factor (gamma), 1.0 = no discount
learning_rate = 0.005 # you know this by now
val_freq = 100 # validation frequency

# setup policy network

policy = PolicyNet(n_inputs, n_hidden, n_outputs, learning_rate)

# train policy network

try:
    training_rewards, losses = [], []
    print('start training')
    for i in range(num_episodes):
        rollout = []
        s = env.reset()
        for j in range(rollout_limit):
            # generate rollout by iteratively evaluating the current policy on the environment
            with torch.no_grad():
                a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                a = torch.multinomial(a_prob, num_samples=1).squeeze().numpy()
            s1, r, done, _ = env.step(a)
            rollout.append((s, a, r))
            s = s1
            if done: break
        # prepare batch
        rollout = np.array(rollout)
        states = np.vstack(rollout[:,0])
        actions = np.vstack(rollout[:,1])
        rewards = np.array(rollout[:,2], dtype=float)
        returns = compute_returns(rewards, discount_factor)
        # policy gradient update
        policy.optimizer.zero_grad()
        a_probs = policy(torch.from_numpy(states).float()).gather(1, torch.from_numpy(actions)).view(-1)
        loss = policy.loss(a_probs, torch.from_numpy(returns).float())
        loss.backward()
        policy.optimizer.step()
        # bookkeeping
        training_rewards.append(sum(rewards))
        losses.append(loss.item())
        # print
        if (i+1) % val_freq == 0:
            # validation
            validation_rewards = []
            for _ in range(10):
                s = env.reset()
                reward = 0
                for _ in range(rollout_limit):
                    with torch.no_grad():
                        a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                        a = a_prob.argmax().item()
                    s, r, done, _ = env.step(a)
                    reward += r
                    if done: break
                validation_rewards.append(reward)
            print('{:4d}. mean training reward: {:6.2f}, mean validation reward: {:6.2f}, mean loss: {:7.4f}'.format(i+1, np.mean(training_rewards[-val_freq:]), np.mean(validation_rewards), np.mean(losses[-val_freq:])))
    print('done')
except KeyboardInterrupt:
    print('interrupt')
# Out:
# start training
#  100. mean training reward:  29.18, mean validation reward:  40.30, mean loss:  9.9832
#  200. mean training reward:  44.33, mean validation reward: 119.70, mean loss: 14.1171
#  300. mean training reward:  71.43, mean validation reward: 143.20, mean loss: 21.6456
#  400. mean training reward: 131.29, mean validation reward: 196.00, mean loss: 37.1305
#  500. mean training reward: 123.65, mean validation reward: 118.60, mean loss: 34.4748
#  600. mean training reward: 173.63, mean validation reward: 200.00, mean loss: 48.1486
#  700. mean training reward: 191.40, mean validation reward: 200.00, mean loss: 54.8188
#  800. mean training reward: 199.46, mean validation reward: 200.00, mean loss: 56.7910
#  900. mean training reward: 194.63, mean validation reward: 200.00, mean loss: 55.7125
# 1000. mean training reward: 186.42, mean validation reward: 200.00, mean loss: 53.0225
# 1100. mean training reward: 194.57, mean validation reward: 200.00, mean loss: 52.4613
# 1200. mean training reward: 190.47, mean validation reward: 200.00, mean loss: 48.8665
# 1300. mean training reward: 184.99, mean validation reward: 200.00, mean loss: 47.0100
# 1400. mean training reward: 195.39, mean validation reward: 200.00, mean loss: 51.1607
# 1500. mean training reward: 199.47, mean validation reward: 200.00, mean loss: 49.3956
# 1600. mean training reward: 194.96, mean validation reward: 200.00, mean loss: 49.4189
# 1700. mean training reward: 198.83, mean validation reward: 200.00, mean loss: 51.0174
# 1800. mean training reward: 160.12, mean validation reward: 200.00, mean loss: 39.6516
# 1900. mean training reward: 194.82, mean validation reward: 200.00, mean loss: 51.5056
# 2000. mean training reward: 198.11, mean validation reward: 200.00, mean loss: 53.4431
# 2100. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 52.1725
# 2200. mean training reward: 199.23, mean validation reward: 200.00, mean loss: 49.8444
# 2300. mean training reward: 198.26, mean validation reward: 200.00, mean loss: 50.8459
# 2400. mean training reward: 144.72, mean validation reward: 135.20, mean loss: 34.8234
# 2500. mean training reward: 190.80, mean validation reward: 200.00, mean loss: 44.4161
# 2600. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 47.0387
# 2700. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 45.8851
# 2800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 45.7410
# 2900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 49.3658
# 3000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 52.0902
# 3100. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 50.4484
# 3200. mean training reward: 198.23, mean validation reward: 200.00, mean loss: 51.8173
# 3300. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 52.2545
# 3400. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 49.7324
# 3500. mean training reward: 198.22, mean validation reward: 200.00, mean loss: 49.4328
# 3600. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 52.9430
# 3700. mean training reward: 173.29, mean validation reward: 200.00, mean loss: 44.6998
# 3800. mean training reward: 163.55, mean validation reward: 200.00, mean loss: 41.5060
# 3900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 51.9773
# 4000. mean training reward: 196.54, mean validation reward: 200.00, mean loss: 47.4958
# 4100. mean training reward: 193.28, mean validation reward: 199.90, mean loss: 46.5650
# 4200. mean training reward: 172.62, mean validation reward: 200.00, mean loss: 38.9394
# 4300. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 45.1276
# 4400. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 40.8211
# 4500. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 40.1565
# 4600. mean training reward: 198.92, mean validation reward: 200.00, mean loss: 40.6336
# 4700. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 41.8001
# 4800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 43.2247
# 4900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 43.2970
# 5000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 45.6369
# 5100. mean training reward: 198.95, mean validation reward: 200.00, mean loss: 47.5497
# 5200. mean training reward: 196.34, mean validation reward: 200.00, mean loss: 49.2011
# 5300. mean training reward: 196.30, mean validation reward: 200.00, mean loss: 50.7343
# 5400. mean training reward: 198.44, mean validation reward: 200.00, mean loss: 51.2528
# 5500. mean training reward: 198.69, mean validation reward: 200.00, mean loss: 47.7743
# 5600. mean training reward: 159.72, mean validation reward: 200.00, mean loss: 36.7151
# 5700. mean training reward: 180.80, mean validation reward: 200.00, mean loss: 42.0205
# 5800. mean training reward: 195.67, mean validation reward: 200.00, mean loss: 45.8212
# 5900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 43.5320
# 6000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 41.6069
# 6100. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 42.7494
# 6200. mean training reward: 178.55, mean validation reward: 200.00, mean loss: 38.0358
# 6300. mean training reward: 170.64, mean validation reward: 200.00, mean loss: 38.5346
# 6400. mean training reward: 198.21, mean validation reward: 200.00, mean loss: 43.8537
# 6500. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 43.7490
# 6600. mean training reward: 192.81, mean validation reward: 200.00, mean loss: 39.1636
# 6700. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 41.6541
# 6800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 41.0743
# 6900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 38.0952
# 7000. mean training reward: 146.49, mean validation reward: 123.50, mean loss: 26.5833
# 7100. mean training reward: 179.03, mean validation reward: 191.60, mean loss: 32.5641
# 7200. mean training reward: 166.19, mean validation reward: 150.50, mean loss: 31.6635
# 7300. mean training reward: 168.07, mean validation reward: 200.00, mean loss: 31.9312
# 7400. mean training reward: 185.76, mean validation reward: 187.20, mean loss: 34.0952
# 7500. mean training reward: 198.09, mean validation reward: 200.00, mean loss: 36.0299
# 7600. mean training reward: 188.86, mean validation reward: 175.50, mean loss: 37.2118
# 7700. mean training reward: 195.70, mean validation reward: 200.00, mean loss: 39.0028
# 7800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 39.0984
# 7900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 37.9288
# 8000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 40.5572
# 8100. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 40.4947
# 8200. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 39.1335
# 8300. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 38.6094
# 8400. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 37.7333
# 8500. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 40.5137
# 8600. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 37.1746
# 8700. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 36.4352
# 8800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 36.1638
# 8900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 34.3900
# 9000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 33.2114
# 9100. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 36.6239
# 9200. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 36.8374
# 9300. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 37.6686
# 9400. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 36.7218
# 9500. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 32.7866
# 9600. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 29.8311
# 9700. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 30.9026
# 9800. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 32.4576
# 9900. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 32.0427
# 10000. mean training reward: 200.00, mean validation reward: 200.00, mean loss: 34.8966
# done

# %%
# plot results
def moving_average(a, n=10) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

plt.figure(figsize=(16,6))
plt.subplot(211)
plt.plot(range(1, len(training_rewards)+1), training_rewards, label='training reward')
plt.plot(moving_average(training_rewards))
plt.xlabel('episode'); plt.ylabel('reward')
plt.xlim((0, len(training_rewards)))
plt.legend(loc=4); plt.grid()
plt.subplot(212)
plt.plot(range(1, len(losses)+1), losses, label='loss')
plt.plot(moving_average(losses))
plt.xlabel('episode'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()

# %% [markdown]
# Now let's review the solution!

# %%
env = wrappers.Monitor(env, "./gym-results", force=True) # Create wrapper to display environment
s = env.reset()

for _ in range(500):
    env.render()
    a = policy(torch.from_numpy(np.atleast_2d(s)).float()).argmax().item()
    s, r, done, _ = env.step(a)
    if done: break
    
env.close()
show_replay()
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# ## Reducing variance
#
# By default, this gradient estimator has high variance and therefore variance reduction becomes important to learn more complex tasks.
# We can reduce variance by subtracting a baseline from the returns, which is unbiased in expectation:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) (R_t-b_t) \ ,
# $$
#
# where the baseline, $b_t$, is estimated by the return a timestep $t$ averaged over $V$ rollouts.
#
# $$
# b_t = \frac{1}{V} \sum_{v=1}^V R_t^{(v)} \ .
# $$

# %% [markdown]
# ## Exercises
#
# Now it is your turn! Make sure you read and understand the code, then play around with it and try to make it learn better and faster.
#
# Experiment with the:
#
# * number of episodes
# * discount factor
# * learning rate
# * network layers
#
#
# ### Exercise 1
#
# *Describe any changes you made to the code and why you think they improve the agent. Are you able to get solutions consistently?*
#
# **Answer:**
#
# Increase the eposodes to 10000 and learning rate to 0.005.
#
# ### Exercise 2
#
# *Consider the following sequence of rewards produced by an agent interacting with an environment for 10 timesteps:*
#
# [0, 1, 1, 1, 0, 1, 1, 0, 0, 0]
#
# * *What is the total reward?*
# * *What is the total future reward in each timestep?*
# * *What is the discounted future reward in each timestep if $\gamma = 0.9$?*
#
# *Hint: See introdution notebook.*
#
# **Answer:**
#
# Total reward is the sum of all rewards: 5
#
# Total future reward is  $R_t = r_t + r_{t+1} + r_{t+2} + \dots + r_T = \sum_{k=0}^{T-t} r_{t+k}$ .Thus we get the vector of future rewards: [5, 5, 4, 3, 3, 2, 1, 0, 0, 0]
#
# Discounted future reward is $R_t = r_t + \gamma r_{t+1} + \gamma^2 r_{t+2} + \dots + \gamma^{T} r_T = \sum_{k=0}^{T-t} \gamma^k r_{t+k} \$.
# So the result is [3.560931, 4.95659, 4.2851, 3.539, 1.71, 2.9, 2.0, 0.0, 0.0, 0.0]
#
# ### Exercise 3
#
# *In the training output, you will sometimes observe the validation reward starts out lower than the training reward but as training progresses they cross over and the validation reward becomes higher than the training reward. How can you explain this behavior?*
#
# *Hint: Do we use the policy network in the same way during training and validation?*
#
# **Answer:**
#
# No, because in training we do continue doing rollouts until we hit time_step greater than or equal to our batch_size while under validation we just do one roll_out of the specified length.
#
#
# ### Exercise 4
#
# *How does the policy gradient method we have used address the exploration-exploitation dilemma?*
#
# *Hint: See the introduction notebook about exploration-exploitation.*
#
# **Answer:**
#
# First we chose a stochastic action based on our policy.In the beginning, all actions have equal propability to be carried out. Then, we updated our policy based on action performance.When we train more, the chance of odd actions becomes less as the networks learns which a good. So you could say that the learning rate determines how fast we go into exploitation mode, as a faster learning rate will change the policy faster and thus the chance of explorative choices becomes smaller as we set on a well-defined strategy in the action space.
#
# ### Exercise 5 [optional]
#
# Extend the code above to reduce variance of the gradient estimator by computing and subtracting the baseline estimate.
#
# *Hint: You need to sample a batch of rollouts (now we sample just one) for each update in order to compute the baseline, $b_t$.*
