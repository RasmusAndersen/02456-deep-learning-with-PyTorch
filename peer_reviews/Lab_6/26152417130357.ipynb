# %% [markdown]
# # Credits
#
# Originally created for a previous version of the [02456-deep-learning](https://github.com/DeepLearningDTU/02456-deep-learning) course material, but [converted to PyTorch](https://github.com/pytorch/tutorials).
# See repos for credits.

# %%
## Install pandas if you don't already have it (uncomment line below)

# ! pip install pandas

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os

from IPython.display import clear_output
from skimage.io import imread
from skimage.transform import resize

import data_utils

#import sys
#sys.path.append(os.path.join('.', '..')) # Allow us to import shared custom 
#                                         # libraries, like utils.py

# %% [markdown]
# #### Tying everything together
#
# Now that you have learned about the three most used network architectures: FFNs, CNNs and RNNs. It is time to combine these network types into a more advanced model.
# It often happens that you have a combination of data that cannot fully be modeled by any one of these three types of network. Knowing how to divide the data into the right subsets, and then build a network that handles each subset efficiently can mean the difference between a great model and an unusable one.
#
# In this notebook we will work on the **Kaggle Leaf Classification Challenge**, a data science competition from [`kaggle.com`](kaggle.com) that contains several different kinds of data.
# First we will download the data and visualize it, and then we will train a network to classify the data.
# A simple network with poor performance is provided for you as a starting point, but it is up to you use the things you have learnt to improve the results.
#
#
# ## Kaggle challenge
# Kaggle is a website to participate in real life challenges.
# Early 2017 it was bought by Google, who wanted access to the global community of data scientists it has created over the last 7 years.
# Since then Google has sponsored its expansion and now the prizes of the competitions and the amount of public datasets are bigger than ever.
# Most competitions on Kaggle have a dataset, an accuracy metric and a leaderboard to compare submissions.
# You can read more about Kaggle public datasets [here](https://www.kaggle.com/datasets).
#
# The challenge we will pursue is the [_Leaf Classification_](https://www.kaggle.com/c/leaf-classification) challenge.
# The dataset consists approximately 1,584 images of leaf specimens which have been converted to binary black leaves against white backgrounds.
# Three sets of features are also provided per image: a shape contiguous descriptor, an interior texture histogram, and a ﬁne-scale margin histogram. For each feature, a 64-attribute vector is given per leaf sample. We will primarily look into the type of neural network best suited for handling this type of data.
#
# Lastly, we will train the model and put the outputs in a submission file that we can submit to Kaggle.

# %% [markdown]
# # Get set up
#
# **NB**: You will need a Kaggle account for this exercise!
#
# 1. Go to [Kaggle](https://www.kaggle.com/), create a user
# 2. [Download the dataset](https://www.kaggle.com/c/leaf-classification/data)
# 3. Unpack the dataset in the current directory. Structure should be as follows:
# ```
# 02456-deep-learning-with-PyTorch\4_Mini_Project
# --> sample_submission.csv
# --> test.csv
# --> train.csv
# --> images
# --> --> 1.jpg
# --> --> 2.jpg
# --> --> 3.jpg
# --> --> ...
# ```
#
# # Upload data to colab
# If you're running this notebook on google colab, you'll need to upload `data_utils.py` that we provide as well as the data you've just downloaded from kaggle to colab. Small files like `data_utils.py` you can simply upload via the folder icon to the left. Files that are uploaded like this, however, will be deleted every time the runtime deconnects. For big files like the kaggle datafolder it's therefore better to:
#
# 1. upload the data to google drive
# 2. mount the google drive (see cell below)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# After going through a quick authorization process you should now have access to the uploaded file via colab. We can check the location of our data like so:

# %%
#!ls drive/'My Drive'

# %% [markdown]
# Let's save the path for later use. Just replace this with your local path if you're not running on colab.

# %%
#drive_path = 'drive/My Drive/'
local_path = r'C:/Users/Marius/Desktop/'

# %% [markdown]
# # Visualizing the data
#
# First we start out by looking at the images.
# You need to load them first!
# Then we load in the training data, which is in CSV format. For this, we use [pandas](https://pandas.pydata.org/).
# Pandas is useful for data analysis, but we don't suggest using it in any production code.

# %%
image_paths = glob.glob("C:/Users/Marius/Desktop/images/*.jpg") # if your path to the 
print("Total Observations:\t", len(image_paths))

# now loading the train.csv to find features for each training point
train = pd.read_csv(r"C:/Users/Marius/Desktop/train.csv")
train_images = ['C:/Users/Marius/Desktop/images/{}.jpg'.format(i) for i in train.id.values]

# now loading the test.csv
test = pd.read_csv('C:/Users/Marius/Desktop/test.csv')
# Out:
# Total Observations:	 1584

# %% [markdown]
# ## Exercise 1
#
# 1.1) How many samples do we have for training and test? Do we have the same information for training and test data? How many samples do we have for each species?
#
# **Hint** You might want to use .shape, .columns, pd.unique() and .symmetric_difference().

# %% [markdown]
#  * **Answer:**

# %% [markdown]
# The training set has 990 samples and the testing one has 594 samples. The training and test set have the same columns, except the training set has an extra one called 'species' with the name of the species. We have 10 samples for each species, and 99 unique species.

# %%
# Your code to produce answers here:
train.shape
# Out:
# (990, 194)

# %%
test.shape
# Out:
# (594, 193)

# %%
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  ...  texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859  ...   0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203  ...   0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719  ...   0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906  ...   0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859  ...   0.000000   0.042969   0.016602   0.010742
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# 0   0.015625        0.0        0.0   0.000000   0.003906   0.053711
# 1   0.013672        0.0        0.0   0.000977   0.037109   0.044922
# 2   0.000000        0.0        0.0   0.015625   0.000000   0.000000
# 3   0.013672        0.0        0.0   0.089844   0.000000   0.008789
# 4   0.041016        0.0        0.0   0.007812   0.009766   0.007812
#
# [5 rows x 193 columns]

# %% [markdown]
# The columns 'species' is not present in the test data. Otherwise they have the same columns.

# %%
train[train.columns.difference(test.columns)]
# Out:
#                    species
# 0              Acer_Opalus
# 1    Pterocarya_Stenoptera
# 2     Quercus_Hartwissiana
# 3          Tilia_Tomentosa
# 4       Quercus_Variabilis
# ..                     ...
# 985   Magnolia_Salicifolia
# 986            Acer_Pictum
# 987     Alnus_Maximowiczii
# 988          Quercus_Rubra
# 989         Quercus_Afares
#
# [990 rows x 1 columns]

# %% [markdown]
# We have 10 samples for each of the 99 species.

# %%
train.groupby('species')['id'].count()
# Out:
# species
# Acer_Capillipes                 10
# Acer_Circinatum                 10
# Acer_Mono                       10
# Acer_Opalus                     10
# Acer_Palmatum                   10
#                                 ..
# Tilia_Tomentosa                 10
# Ulmus_Bergmanniana              10
# Viburnum_Tinus                  10
# Viburnum_x_Rhytidophylloides    10
# Zelkova_Serrata                 10
# Name: id, Length: 99, dtype: int64

# %%
dfx = train.columns.values.tolist()
dfx = pd.Index(dfx)

# %%
dfy = test.columns.values.tolist()
dfy = pd.Index(dfy)

# %%
dfx.symmetric_difference(dfy)
# Out:
# Index(['species'], dtype='object')

# %% [markdown]
# With our training data and images loaded into memory.
# It is time to take a look at the data.
# Trying to classify leaves does not sound like a particularly difficult or interesting problem.
# We have probably all had teachers forcing us to do it on field trips as children.
#
# But try to take a look at **all** the different categories and come up with a system that discern **all** types of leaves from each other. (In fact, distinguishing crops from weed using AI is already a thing: [weed-killing AI](https://www.cnbc.com/2018/06/04/weed-killing-ai-robot.html).)

# %%
# First we find an example of each species in order to visualize it
species = np.array(sorted(train.species.unique()))
species_examples = [np.random.choice(train[train.species == s].id.values) for s in species]

# Then we gather its' index in our list of images in order to find the correct image
indexes = [image_paths.index("C:/Users/Marius/Desktop/images\\{}.jpg".format(i)) for i in species_examples]

# Plot of the first image
plt.figure(figsize=(8, 8))
image = imread(image_paths[98], as_gray=True)
plt.imshow(image, cmap='gray')
plt.title("%s" % (species[98]))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Exercise 2
# 2.1) In general it is a good approach to visualize an image for each category to get a better feeling of the task. You should now write some code to show 1 image from each category. You might want to use plt.subplot().

# %%
# Now plot 1 image from each category:
image_paths
# Out:
# ['C:/Users/Marius/Desktop/images\\1.jpg',
#  'C:/Users/Marius/Desktop/images\\10.jpg',
#  'C:/Users/Marius/Desktop/images\\100.jpg',
#  'C:/Users/Marius/Desktop/images\\1000.jpg',
#  'C:/Users/Marius/Desktop/images\\1001.jpg',
#  'C:/Users/Marius/Desktop/images\\1002.jpg',
#  'C:/Users/Marius/Desktop/images\\1003.jpg',
#  'C:/Users/Marius/Desktop/images\\1004.jpg',
#  'C:/Users/Marius/Desktop/images\\1005.jpg',
#  'C:/Users/Marius/Desktop/images\\1006.jpg',
#  'C:/Users/Marius/Desktop/images\\1007.jpg',
#  'C:/Users/Marius/Desktop/images\\1008.jpg',
#  'C:/Users/Marius/Desktop/images\\1009.jpg',
#  'C:/Users/Marius/Desktop/images\\101.jpg',
#  'C:/Users/Marius/Desktop/images\\1010.jpg',
#  'C:/Users/Marius/Desktop/images\\1011.jpg',
#  'C:/Users/Marius/Desktop/images\\1012.jpg',
#  'C:/Users/Marius/Desktop/images\\1013.jpg',
#  'C:/Users/Marius/Desktop/images\\1014.jpg',
#  'C:/Users/Marius/Desktop/images\\1015.jpg',
#  'C:/Users/Marius/Desktop/images\\1016.jpg',
#  'C:/Users/Marius/Desktop/images\\1017.jpg',
#  'C:/Users/Marius/Desktop/images\\1018.jpg',
#  'C:/Users/Marius/Desktop/images\\1019.jpg',
#  'C:/Users/Marius/Desktop/images\\102.jpg',
#  'C:/Users/Marius/Desktop/images\\1020.jpg',
#  'C:/Users/Marius/Desktop/images\\1021.jpg',
#  'C:/Users/Marius/Desktop/images\\1022.jpg',
#  'C:/Users/Marius/Desktop/images\\1023.jpg',
#  'C:/Users/Marius/Desktop/images\\1024.jpg',
#  'C:/Users/Marius/Desktop/images\\1025.jpg',
#  'C:/Users/Marius/Desktop/images\\1026.jpg',
#  'C:/Users/Marius/Desktop/images\\1027.jpg',
#  'C:/Users/Marius/Desktop/images\\1028.jpg',
#  'C:/Users/Marius/Desktop/images\\1029.jpg',
#  'C:/Users/Marius/Desktop/images\\103.jpg',
#  'C:/Users/Marius/Desktop/images\\1030.jpg',
#  'C:/Users/Marius/Desktop/images\\1031.jpg',
#  'C:/Users/Marius/Desktop/images\\1032.jpg',
#  'C:/Users/Marius/Desktop/images\\1033.jpg',
#  'C:/Users/Marius/Desktop/images\\1034.jpg',
#  'C:/Users/Marius/Desktop/images\\1035.jpg',
#  'C:/Users/Marius/Desktop/images\\1036.jpg',
#  'C:/Users/Marius/Desktop/images\\1037.jpg',
#  'C:/Users/Marius/Desktop/images\\1038.jpg',
#  'C:/Users/Marius/Desktop/images\\1039.jpg',
#  'C:/Users/Marius/Desktop/images\\104.jpg',
#  'C:/Users/Marius/Desktop/images\\1040.jpg',
#  'C:/Users/Marius/Desktop/images\\1041.jpg',
#  'C:/Users/Marius/Desktop/images\\1042.jpg',
#  'C:/Users/Marius/Desktop/images\\1043.jpg',
#  'C:/Users/Marius/Desktop/images\\1044.jpg',
#  'C:/Users/Marius/Desktop/images\\1045.jpg',
#  'C:/Users/Marius/Desktop/images\\1046.jpg',
#  'C:/Users/Marius/Desktop/images\\1047.jpg',
#  'C:/Users/Marius/Desktop/images\\1048.jpg',
#  'C:/Users/Marius/Desktop/images\\1049.jpg',
#  'C:/Users/Marius/Desktop/images\\105.jpg',
#  'C:/Users/Marius/Desktop/images\\1050.jpg',
#  'C:/Users/Marius/Desktop/images\\1051.jpg',
#  'C:/Users/Marius/Desktop/images\\1052.jpg',
#  'C:/Users/Marius/Desktop/images\\1053.jpg',
#  'C:/Users/Marius/Desktop/images\\1054.jpg',
#  'C:/Users/Marius/Desktop/images\\1055.jpg',
#  'C:/Users/Marius/Desktop/images\\1056.jpg',
#  'C:/Users/Marius/Desktop/images\\1057.jpg',
#  'C:/Users/Marius/Desktop/images\\1058.jpg',
#  'C:/Users/Marius/Desktop/images\\1059.jpg',
#  'C:/Users/Marius/Desktop/images\\106.jpg',
#  'C:/Users/Marius/Desktop/images\\1060.jpg',
#  'C:/Users/Marius/Desktop/images\\1061.jpg',
#  'C:/Users/Marius/Desktop/images\\1062.jpg',
#  'C:/Users/Marius/Desktop/images\\1063.jpg',
#  'C:/Users/Marius/Desktop/images\\1064.jpg',
#  'C:/Users/Marius/Desktop/images\\1065.jpg',
#  'C:/Users/Marius/Desktop/images\\1066.jpg',
#  'C:/Users/Marius/Desktop/images\\1067.jpg',
#  'C:/Users/Marius/Desktop/images\\1068.jpg',
#  'C:/Users/Marius/Desktop/images\\1069.jpg',
#  'C:/Users/Marius/Desktop/images\\107.jpg',
#  'C:/Users/Marius/Desktop/images\\1070.jpg',
#  'C:/Users/Marius/Desktop/images\\1071.jpg',
#  'C:/Users/Marius/Desktop/images\\1072.jpg',
#  'C:/Users/Marius/Desktop/images\\1073.jpg',
#  'C:/Users/Marius/Desktop/images\\1074.jpg',
#  'C:/Users/Marius/Desktop/images\\1075.jpg',
#  'C:/Users/Marius/Desktop/images\\1076.jpg',
#  'C:/Users/Marius/Desktop/images\\1077.jpg',
#  'C:/Users/Marius/Desktop/images\\1078.jpg',
#  'C:/Users/Marius/Desktop/images\\1079.jpg',
#  'C:/Users/Marius/Desktop/images\\108.jpg',
#  'C:/Users/Marius/Desktop/images\\1080.jpg',
#  'C:/Users/Marius/Desktop/images\\1081.jpg',
#  'C:/Users/Marius/Desktop/images\\1082.jpg',
#  'C:/Users/Marius/Desktop/images\\1083.jpg',
#  'C:/Users/Marius/Desktop/images\\1084.jpg',
#  'C:/Users/Marius/Desktop/images\\1085.jpg',
#  'C:/Users/Marius/Desktop/images\\1086.jpg',
#  'C:/Users/Marius/Desktop/images\\1087.jpg',
#  'C:/Users/Marius/Desktop/images\\1088.jpg',
#  'C:/Users/Marius/Desktop/images\\1089.jpg',
#  'C:/Users/Marius/Desktop/images\\109.jpg',
#  'C:/Users/Marius/Desktop/images\\1090.jpg',
#  'C:/Users/Marius/Desktop/images\\1091.jpg',
#  'C:/Users/Marius/Desktop/images\\1092.jpg',
#  'C:/Users/Marius/Desktop/images\\1093.jpg',
#  'C:/Users/Marius/Desktop/images\\1094.jpg',
#  'C:/Users/Marius/Desktop/images\\1095.jpg',
#  'C:/Users/Marius/Desktop/images\\1096.jpg',
#  'C:/Users/Marius/Desktop/images\\1097.jpg',
#  'C:/Users/Marius/Desktop/images\\1098.jpg',
#  'C:/Users/Marius/Desktop/images\\1099.jpg',
#  'C:/Users/Marius/Desktop/images\\11.jpg',
#  'C:/Users/Marius/Desktop/images\\110.jpg',
#  'C:/Users/Marius/Desktop/images\\1100.jpg',
#  'C:/Users/Marius/Desktop/images\\1101.jpg',
#  'C:/Users/Marius/Desktop/images\\1102.jpg',
#  'C:/Users/Marius/Desktop/images\\1103.jpg',
#  'C:/Users/Marius/Desktop/images\\1104.jpg',
#  'C:/Users/Marius/Desktop/images\\1105.jpg',
#  'C:/Users/Marius/Desktop/images\\1106.jpg',
#  'C:/Users/Marius/Desktop/images\\1107.jpg',
#  'C:/Users/Marius/Desktop/images\\1108.jpg',
#  'C:/Users/Marius/Desktop/images\\1109.jpg',
#  'C:/Users/Marius/Desktop/images\\111.jpg',
#  'C:/Users/Marius/Desktop/images\\1110.jpg',
#  'C:/Users/Marius/Desktop/images\\1111.jpg',
#  'C:/Users/Marius/Desktop/images\\1112.jpg',
#  'C:/Users/Marius/Desktop/images\\1113.jpg',
#  'C:/Users/Marius/Desktop/images\\1114.jpg',
#  'C:/Users/Marius/Desktop/images\\1115.jpg',
#  'C:/Users/Marius/Desktop/images\\1116.jpg',
#  'C:/Users/Marius/Desktop/images\\1117.jpg',
#  'C:/Users/Marius/Desktop/images\\1118.jpg',
#  'C:/Users/Marius/Desktop/images\\1119.jpg',
#  'C:/Users/Marius/Desktop/images\\112.jpg',
#  'C:/Users/Marius/Desktop/images\\1120.jpg',
#  'C:/Users/Marius/Desktop/images\\1121.jpg',
#  'C:/Users/Marius/Desktop/images\\1122.jpg',
#  'C:/Users/Marius/Desktop/images\\1123.jpg',
#  'C:/Users/Marius/Desktop/images\\1124.jpg',
#  'C:/Users/Marius/Desktop/images\\1125.jpg',
#  'C:/Users/Marius/Desktop/images\\1126.jpg',
#  'C:/Users/Marius/Desktop/images\\1127.jpg',
#  'C:/Users/Marius/Desktop/images\\1128.jpg',
#  'C:/Users/Marius/Desktop/images\\1129.jpg',
#  'C:/Users/Marius/Desktop/images\\113.jpg',
#  'C:/Users/Marius/Desktop/images\\1130.jpg',
#  'C:/Users/Marius/Desktop/images\\1131.jpg',
#  'C:/Users/Marius/Desktop/images\\1132.jpg',
#  'C:/Users/Marius/Desktop/images\\1133.jpg',
#  'C:/Users/Marius/Desktop/images\\1134.jpg',
#  'C:/Users/Marius/Desktop/images\\1135.jpg',
#  'C:/Users/Marius/Desktop/images\\1136.jpg',
#  'C:/Users/Marius/Desktop/images\\1137.jpg',
#  'C:/Users/Marius/Desktop/images\\1138.jpg',
#  'C:/Users/Marius/Desktop/images\\1139.jpg',
#  'C:/Users/Marius/Desktop/images\\114.jpg',
#  'C:/Users/Marius/Desktop/images\\1140.jpg',
#  'C:/Users/Marius/Desktop/images\\1141.jpg',
#  'C:/Users/Marius/Desktop/images\\1142.jpg',
#  'C:/Users/Marius/Desktop/images\\1143.jpg',
#  'C:/Users/Marius/Desktop/images\\1144.jpg',
#  'C:/Users/Marius/Desktop/images\\1145.jpg',
#  'C:/Users/Marius/Desktop/images\\1146.jpg',
#  'C:/Users/Marius/Desktop/images\\1147.jpg',
#  'C:/Users/Marius/Desktop/images\\1148.jpg',
#  'C:/Users/Marius/Desktop/images\\1149.jpg',
#  'C:/Users/Marius/Desktop/images\\115.jpg',
#  'C:/Users/Marius/Desktop/images\\1150.jpg',
#  'C:/Users/Marius/Desktop/images\\1151.jpg',
#  'C:/Users/Marius/Desktop/images\\1152.jpg',
#  'C:/Users/Marius/Desktop/images\\1153.jpg',
#  'C:/Users/Marius/Desktop/images\\1154.jpg',
#  'C:/Users/Marius/Desktop/images\\1155.jpg',
#  'C:/Users/Marius/Desktop/images\\1156.jpg',
#  'C:/Users/Marius/Desktop/images\\1157.jpg',
#  'C:/Users/Marius/Desktop/images\\1158.jpg',
#  'C:/Users/Marius/Desktop/images\\1159.jpg',
#  'C:/Users/Marius/Desktop/images\\116.jpg',
#  'C:/Users/Marius/Desktop/images\\1160.jpg',
#  'C:/Users/Marius/Desktop/images\\1161.jpg',
#  'C:/Users/Marius/Desktop/images\\1162.jpg',
#  'C:/Users/Marius/Desktop/images\\1163.jpg',
#  'C:/Users/Marius/Desktop/images\\1164.jpg',
#  'C:/Users/Marius/Desktop/images\\1165.jpg',
#  'C:/Users/Marius/Desktop/images\\1166.jpg',
#  'C:/Users/Marius/Desktop/images\\1167.jpg',
#  'C:/Users/Marius/Desktop/images\\1168.jpg',
#  'C:/Users/Marius/Desktop/images\\1169.jpg',
#  'C:/Users/Marius/Desktop/images\\117.jpg',
#  'C:/Users/Marius/Desktop/images\\1170.jpg',
#  'C:/Users/Marius/Desktop/images\\1171.jpg',
#  'C:/Users/Marius/Desktop/images\\1172.jpg',
#  'C:/Users/Marius/Desktop/images\\1173.jpg',
#  'C:/Users/Marius/Desktop/images\\1174.jpg',
#  'C:/Users/Marius/Desktop/images\\1175.jpg',
#  'C:/Users/Marius/Desktop/images\\1176.jpg',
#  'C:/Users/Marius/Desktop/images\\1177.jpg',
#  'C:/Users/Marius/Desktop/images\\1178.jpg',
#  'C:/Users/Marius/Desktop/images\\1179.jpg',
#  'C:/Users/Marius/Desktop/images\\118.jpg',
#  'C:/Users/Marius/Desktop/images\\1180.jpg',
#  'C:/Users/Marius/Desktop/images\\1181.jpg',
#  'C:/Users/Marius/Desktop/images\\1182.jpg',
#  'C:/Users/Marius/Desktop/images\\1183.jpg',
#  'C:/Users/Marius/Desktop/images\\1184.jpg',
#  'C:/Users/Marius/Desktop/images\\1185.jpg',
#  'C:/Users/Marius/Desktop/images\\1186.jpg',
#  'C:/Users/Marius/Desktop/images\\1187.jpg',
#  'C:/Users/Marius/Desktop/images\\1188.jpg',
#  'C:/Users/Marius/Desktop/images\\1189.jpg',
#  'C:/Users/Marius/Desktop/images\\119.jpg',
#  'C:/Users/Marius/Desktop/images\\1190.jpg',
#  'C:/Users/Marius/Desktop/images\\1191.jpg',
#  'C:/Users/Marius/Desktop/images\\1192.jpg',
#  'C:/Users/Marius/Desktop/images\\1193.jpg',
#  'C:/Users/Marius/Desktop/images\\1194.jpg',
#  'C:/Users/Marius/Desktop/images\\1195.jpg',
#  'C:/Users/Marius/Desktop/images\\1196.jpg',
#  'C:/Users/Marius/Desktop/images\\1197.jpg',
#  'C:/Users/Marius/Desktop/images\\1198.jpg',
#  'C:/Users/Marius/Desktop/images\\1199.jpg',
#  'C:/Users/Marius/Desktop/images\\12.jpg',
#  'C:/Users/Marius/Desktop/images\\120.jpg',
#  'C:/Users/Marius/Desktop/images\\1200.jpg',
#  'C:/Users/Marius/Desktop/images\\1201.jpg',
#  'C:/Users/Marius/Desktop/images\\1202.jpg',
#  'C:/Users/Marius/Desktop/images\\1203.jpg',
#  'C:/Users/Marius/Desktop/images\\1204.jpg',
#  'C:/Users/Marius/Desktop/images\\1205.jpg',
#  'C:/Users/Marius/Desktop/images\\1206.jpg',
#  'C:/Users/Marius/Desktop/images\\1207.jpg',
#  'C:/Users/Marius/Desktop/images\\1208.jpg',
#  'C:/Users/Marius/Desktop/images\\1209.jpg',
#  'C:/Users/Marius/Desktop/images\\121.jpg',
#  'C:/Users/Marius/Desktop/images\\1210.jpg',
#  'C:/Users/Marius/Desktop/images\\1211.jpg',
#  'C:/Users/Marius/Desktop/images\\1212.jpg',
#  'C:/Users/Marius/Desktop/images\\1213.jpg',
#  'C:/Users/Marius/Desktop/images\\1214.jpg',
#  'C:/Users/Marius/Desktop/images\\1215.jpg',
#  'C:/Users/Marius/Desktop/images\\1216.jpg',
#  'C:/Users/Marius/Desktop/images\\1217.jpg',
#  'C:/Users/Marius/Desktop/images\\1218.jpg',
#  'C:/Users/Marius/Desktop/images\\1219.jpg',
#  'C:/Users/Marius/Desktop/images\\122.jpg',
#  'C:/Users/Marius/Desktop/images\\1220.jpg',
#  'C:/Users/Marius/Desktop/images\\1221.jpg',
#  'C:/Users/Marius/Desktop/images\\1222.jpg',
#  'C:/Users/Marius/Desktop/images\\1223.jpg',
#  'C:/Users/Marius/Desktop/images\\1224.jpg',
#  'C:/Users/Marius/Desktop/images\\1225.jpg',
#  'C:/Users/Marius/Desktop/images\\1226.jpg',
#  'C:/Users/Marius/Desktop/images\\1227.jpg',
#  'C:/Users/Marius/Desktop/images\\1228.jpg',
#  'C:/Users/Marius/Desktop/images\\1229.jpg',
#  'C:/Users/Marius/Desktop/images\\123.jpg',
#  'C:/Users/Marius/Desktop/images\\1230.jpg',
#  'C:/Users/Marius/Desktop/images\\1231.jpg',
#  'C:/Users/Marius/Desktop/images\\1232.jpg',
#  'C:/Users/Marius/Desktop/images\\1233.jpg',
#  'C:/Users/Marius/Desktop/images\\1234.jpg',
#  'C:/Users/Marius/Desktop/images\\1235.jpg',
#  'C:/Users/Marius/Desktop/images\\1236.jpg',
#  'C:/Users/Marius/Desktop/images\\1237.jpg',
#  'C:/Users/Marius/Desktop/images\\1238.jpg',
#  'C:/Users/Marius/Desktop/images\\1239.jpg',
#  'C:/Users/Marius/Desktop/images\\124.jpg',
#  'C:/Users/Marius/Desktop/images\\1240.jpg',
#  'C:/Users/Marius/Desktop/images\\1241.jpg',
#  'C:/Users/Marius/Desktop/images\\1242.jpg',
#  'C:/Users/Marius/Desktop/images\\1243.jpg',
#  'C:/Users/Marius/Desktop/images\\1244.jpg',
#  'C:/Users/Marius/Desktop/images\\1245.jpg',
#  'C:/Users/Marius/Desktop/images\\1246.jpg',
#  'C:/Users/Marius/Desktop/images\\1247.jpg',
#  'C:/Users/Marius/Desktop/images\\1248.jpg',
#  'C:/Users/Marius/Desktop/images\\1249.jpg',
#  'C:/Users/Marius/Desktop/images\\125.jpg',
#  'C:/Users/Marius/Desktop/images\\1250.jpg',
#  'C:/Users/Marius/Desktop/images\\1251.jpg',
#  'C:/Users/Marius/Desktop/images\\1252.jpg',
#  'C:/Users/Marius/Desktop/images\\1253.jpg',
#  'C:/Users/Marius/Desktop/images\\1254.jpg',
#  'C:/Users/Marius/Desktop/images\\1255.jpg',
#  'C:/Users/Marius/Desktop/images\\1256.jpg',
#  'C:/Users/Marius/Desktop/images\\1257.jpg',
#  'C:/Users/Marius/Desktop/images\\1258.jpg',
#  'C:/Users/Marius/Desktop/images\\1259.jpg',
#  'C:/Users/Marius/Desktop/images\\126.jpg',
#  'C:/Users/Marius/Desktop/images\\1260.jpg',
#  'C:/Users/Marius/Desktop/images\\1261.jpg',
#  'C:/Users/Marius/Desktop/images\\1262.jpg',
#  'C:/Users/Marius/Desktop/images\\1263.jpg',
#  'C:/Users/Marius/Desktop/images\\1264.jpg',
#  'C:/Users/Marius/Desktop/images\\1265.jpg',
#  'C:/Users/Marius/Desktop/images\\1266.jpg',
#  'C:/Users/Marius/Desktop/images\\1267.jpg',
#  'C:/Users/Marius/Desktop/images\\1268.jpg',
#  'C:/Users/Marius/Desktop/images\\1269.jpg',
#  'C:/Users/Marius/Desktop/images\\127.jpg',
#  'C:/Users/Marius/Desktop/images\\1270.jpg',
#  'C:/Users/Marius/Desktop/images\\1271.jpg',
#  'C:/Users/Marius/Desktop/images\\1272.jpg',
#  'C:/Users/Marius/Desktop/images\\1273.jpg',
#  'C:/Users/Marius/Desktop/images\\1274.jpg',
#  'C:/Users/Marius/Desktop/images\\1275.jpg',
#  'C:/Users/Marius/Desktop/images\\1276.jpg',
#  'C:/Users/Marius/Desktop/images\\1277.jpg',
#  'C:/Users/Marius/Desktop/images\\1278.jpg',
#  'C:/Users/Marius/Desktop/images\\1279.jpg',
#  'C:/Users/Marius/Desktop/images\\128.jpg',
#  'C:/Users/Marius/Desktop/images\\1280.jpg',
#  'C:/Users/Marius/Desktop/images\\1281.jpg',
#  'C:/Users/Marius/Desktop/images\\1282.jpg',
#  'C:/Users/Marius/Desktop/images\\1283.jpg',
#  'C:/Users/Marius/Desktop/images\\1284.jpg',
#  'C:/Users/Marius/Desktop/images\\1285.jpg',
#  'C:/Users/Marius/Desktop/images\\1286.jpg',
#  'C:/Users/Marius/Desktop/images\\1287.jpg',
#  'C:/Users/Marius/Desktop/images\\1288.jpg',
#  'C:/Users/Marius/Desktop/images\\1289.jpg',
#  'C:/Users/Marius/Desktop/images\\129.jpg',
#  'C:/Users/Marius/Desktop/images\\1290.jpg',
#  'C:/Users/Marius/Desktop/images\\1291.jpg',
#  'C:/Users/Marius/Desktop/images\\1292.jpg',
#  'C:/Users/Marius/Desktop/images\\1293.jpg',
#  'C:/Users/Marius/Desktop/images\\1294.jpg',
#  'C:/Users/Marius/Desktop/images\\1295.jpg',
#  'C:/Users/Marius/Desktop/images\\1296.jpg',
#  'C:/Users/Marius/Desktop/images\\1297.jpg',
#  'C:/Users/Marius/Desktop/images\\1298.jpg',
#  'C:/Users/Marius/Desktop/images\\1299.jpg',
#  'C:/Users/Marius/Desktop/images\\13.jpg',
#  'C:/Users/Marius/Desktop/images\\130.jpg',
#  'C:/Users/Marius/Desktop/images\\1300.jpg',
#  'C:/Users/Marius/Desktop/images\\1301.jpg',
#  'C:/Users/Marius/Desktop/images\\1302.jpg',
#  'C:/Users/Marius/Desktop/images\\1303.jpg',
#  'C:/Users/Marius/Desktop/images\\1304.jpg',
#  'C:/Users/Marius/Desktop/images\\1305.jpg',
#  'C:/Users/Marius/Desktop/images\\1306.jpg',
#  'C:/Users/Marius/Desktop/images\\1307.jpg',
#  'C:/Users/Marius/Desktop/images\\1308.jpg',
#  'C:/Users/Marius/Desktop/images\\1309.jpg',
#  'C:/Users/Marius/Desktop/images\\131.jpg',
#  'C:/Users/Marius/Desktop/images\\1310.jpg',
#  'C:/Users/Marius/Desktop/images\\1311.jpg',
#  'C:/Users/Marius/Desktop/images\\1312.jpg',
#  'C:/Users/Marius/Desktop/images\\1313.jpg',
#  'C:/Users/Marius/Desktop/images\\1314.jpg',
#  'C:/Users/Marius/Desktop/images\\1315.jpg',
#  'C:/Users/Marius/Desktop/images\\1316.jpg',
#  'C:/Users/Marius/Desktop/images\\1317.jpg',
#  'C:/Users/Marius/Desktop/images\\1318.jpg',
#  'C:/Users/Marius/Desktop/images\\1319.jpg',
#  'C:/Users/Marius/Desktop/images\\132.jpg',
#  'C:/Users/Marius/Desktop/images\\1320.jpg',
#  'C:/Users/Marius/Desktop/images\\1321.jpg',
#  'C:/Users/Marius/Desktop/images\\1322.jpg',
#  'C:/Users/Marius/Desktop/images\\1323.jpg',
#  'C:/Users/Marius/Desktop/images\\1324.jpg',
#  'C:/Users/Marius/Desktop/images\\1325.jpg',
#  'C:/Users/Marius/Desktop/images\\1326.jpg',
#  'C:/Users/Marius/Desktop/images\\1327.jpg',
#  'C:/Users/Marius/Desktop/images\\1328.jpg',
#  'C:/Users/Marius/Desktop/images\\1329.jpg',
#  'C:/Users/Marius/Desktop/images\\133.jpg',
#  'C:/Users/Marius/Desktop/images\\1330.jpg',
#  'C:/Users/Marius/Desktop/images\\1331.jpg',
#  'C:/Users/Marius/Desktop/images\\1332.jpg',
#  'C:/Users/Marius/Desktop/images\\1333.jpg',
#  'C:/Users/Marius/Desktop/images\\1334.jpg',
#  'C:/Users/Marius/Desktop/images\\1335.jpg',
#  'C:/Users/Marius/Desktop/images\\1336.jpg',
#  'C:/Users/Marius/Desktop/images\\1337.jpg',
#  'C:/Users/Marius/Desktop/images\\1338.jpg',
#  'C:/Users/Marius/Desktop/images\\1339.jpg',
#  'C:/Users/Marius/Desktop/images\\134.jpg',
#  'C:/Users/Marius/Desktop/images\\1340.jpg',
#  'C:/Users/Marius/Desktop/images\\1341.jpg',
#  'C:/Users/Marius/Desktop/images\\1342.jpg',
#  'C:/Users/Marius/Desktop/images\\1343.jpg',
#  'C:/Users/Marius/Desktop/images\\1344.jpg',
#  'C:/Users/Marius/Desktop/images\\1345.jpg',
#  'C:/Users/Marius/Desktop/images\\1346.jpg',
#  'C:/Users/Marius/Desktop/images\\1347.jpg',
#  'C:/Users/Marius/Desktop/images\\1348.jpg',
#  'C:/Users/Marius/Desktop/images\\1349.jpg',
#  'C:/Users/Marius/Desktop/images\\135.jpg',
#  'C:/Users/Marius/Desktop/images\\1350.jpg',
#  'C:/Users/Marius/Desktop/images\\1351.jpg',
#  'C:/Users/Marius/Desktop/images\\1352.jpg',
#  'C:/Users/Marius/Desktop/images\\1353.jpg',
#  'C:/Users/Marius/Desktop/images\\1354.jpg',
#  'C:/Users/Marius/Desktop/images\\1355.jpg',
#  'C:/Users/Marius/Desktop/images\\1356.jpg',
#  'C:/Users/Marius/Desktop/images\\1357.jpg',
#  'C:/Users/Marius/Desktop/images\\1358.jpg',
#  'C:/Users/Marius/Desktop/images\\1359.jpg',
#  'C:/Users/Marius/Desktop/images\\136.jpg',
#  'C:/Users/Marius/Desktop/images\\1360.jpg',
#  'C:/Users/Marius/Desktop/images\\1361.jpg',
#  'C:/Users/Marius/Desktop/images\\1362.jpg',
#  'C:/Users/Marius/Desktop/images\\1363.jpg',
#  'C:/Users/Marius/Desktop/images\\1364.jpg',
#  'C:/Users/Marius/Desktop/images\\1365.jpg',
#  'C:/Users/Marius/Desktop/images\\1366.jpg',
#  'C:/Users/Marius/Desktop/images\\1367.jpg',
#  'C:/Users/Marius/Desktop/images\\1368.jpg',
#  'C:/Users/Marius/Desktop/images\\1369.jpg',
#  'C:/Users/Marius/Desktop/images\\137.jpg',
#  'C:/Users/Marius/Desktop/images\\1370.jpg',
#  'C:/Users/Marius/Desktop/images\\1371.jpg',
#  'C:/Users/Marius/Desktop/images\\1372.jpg',
#  'C:/Users/Marius/Desktop/images\\1373.jpg',
#  'C:/Users/Marius/Desktop/images\\1374.jpg',
#  'C:/Users/Marius/Desktop/images\\1375.jpg',
#  'C:/Users/Marius/Desktop/images\\1376.jpg',
#  'C:/Users/Marius/Desktop/images\\1377.jpg',
#  'C:/Users/Marius/Desktop/images\\1378.jpg',
#  'C:/Users/Marius/Desktop/images\\1379.jpg',
#  'C:/Users/Marius/Desktop/images\\138.jpg',
#  'C:/Users/Marius/Desktop/images\\1380.jpg',
#  'C:/Users/Marius/Desktop/images\\1381.jpg',
#  'C:/Users/Marius/Desktop/images\\1382.jpg',
#  'C:/Users/Marius/Desktop/images\\1383.jpg',
#  'C:/Users/Marius/Desktop/images\\1384.jpg',
#  'C:/Users/Marius/Desktop/images\\1385.jpg',
#  'C:/Users/Marius/Desktop/images\\1386.jpg',
#  'C:/Users/Marius/Desktop/images\\1387.jpg',
#  'C:/Users/Marius/Desktop/images\\1388.jpg',
#  'C:/Users/Marius/Desktop/images\\1389.jpg',
#  'C:/Users/Marius/Desktop/images\\139.jpg',
#  'C:/Users/Marius/Desktop/images\\1390.jpg',
#  'C:/Users/Marius/Desktop/images\\1391.jpg',
#  'C:/Users/Marius/Desktop/images\\1392.jpg',
#  'C:/Users/Marius/Desktop/images\\1393.jpg',
#  'C:/Users/Marius/Desktop/images\\1394.jpg',
#  'C:/Users/Marius/Desktop/images\\1395.jpg',
#  'C:/Users/Marius/Desktop/images\\1396.jpg',
#  'C:/Users/Marius/Desktop/images\\1397.jpg',
#  'C:/Users/Marius/Desktop/images\\1398.jpg',
#  'C:/Users/Marius/Desktop/images\\1399.jpg',
#  'C:/Users/Marius/Desktop/images\\14.jpg',
#  'C:/Users/Marius/Desktop/images\\140.jpg',
#  'C:/Users/Marius/Desktop/images\\1400.jpg',
#  'C:/Users/Marius/Desktop/images\\1401.jpg',
#  'C:/Users/Marius/Desktop/images\\1402.jpg',
#  'C:/Users/Marius/Desktop/images\\1403.jpg',
#  'C:/Users/Marius/Desktop/images\\1404.jpg',
#  'C:/Users/Marius/Desktop/images\\1405.jpg',
#  'C:/Users/Marius/Desktop/images\\1406.jpg',
#  'C:/Users/Marius/Desktop/images\\1407.jpg',
#  'C:/Users/Marius/Desktop/images\\1408.jpg',
#  'C:/Users/Marius/Desktop/images\\1409.jpg',
#  'C:/Users/Marius/Desktop/images\\141.jpg',
#  'C:/Users/Marius/Desktop/images\\1410.jpg',
#  'C:/Users/Marius/Desktop/images\\1411.jpg',
#  'C:/Users/Marius/Desktop/images\\1412.jpg',
#  'C:/Users/Marius/Desktop/images\\1413.jpg',
#  'C:/Users/Marius/Desktop/images\\1414.jpg',
#  'C:/Users/Marius/Desktop/images\\1415.jpg',
#  'C:/Users/Marius/Desktop/images\\1416.jpg',
#  'C:/Users/Marius/Desktop/images\\1417.jpg',
#  'C:/Users/Marius/Desktop/images\\1418.jpg',
#  'C:/Users/Marius/Desktop/images\\1419.jpg',
#  'C:/Users/Marius/Desktop/images\\142.jpg',
#  'C:/Users/Marius/Desktop/images\\1420.jpg',
#  'C:/Users/Marius/Desktop/images\\1421.jpg',
#  'C:/Users/Marius/Desktop/images\\1422.jpg',
#  'C:/Users/Marius/Desktop/images\\1423.jpg',
#  'C:/Users/Marius/Desktop/images\\1424.jpg',
#  'C:/Users/Marius/Desktop/images\\1425.jpg',
#  'C:/Users/Marius/Desktop/images\\1426.jpg',
#  'C:/Users/Marius/Desktop/images\\1427.jpg',
#  'C:/Users/Marius/Desktop/images\\1428.jpg',
#  'C:/Users/Marius/Desktop/images\\1429.jpg',
#  'C:/Users/Marius/Desktop/images\\143.jpg',
#  'C:/Users/Marius/Desktop/images\\1430.jpg',
#  'C:/Users/Marius/Desktop/images\\1431.jpg',
#  'C:/Users/Marius/Desktop/images\\1432.jpg',
#  'C:/Users/Marius/Desktop/images\\1433.jpg',
#  'C:/Users/Marius/Desktop/images\\1434.jpg',
#  'C:/Users/Marius/Desktop/images\\1435.jpg',
#  'C:/Users/Marius/Desktop/images\\1436.jpg',
#  'C:/Users/Marius/Desktop/images\\1437.jpg',
#  'C:/Users/Marius/Desktop/images\\1438.jpg',
#  'C:/Users/Marius/Desktop/images\\1439.jpg',
#  'C:/Users/Marius/Desktop/images\\144.jpg',
#  'C:/Users/Marius/Desktop/images\\1440.jpg',
#  'C:/Users/Marius/Desktop/images\\1441.jpg',
#  'C:/Users/Marius/Desktop/images\\1442.jpg',
#  'C:/Users/Marius/Desktop/images\\1443.jpg',
#  'C:/Users/Marius/Desktop/images\\1444.jpg',
#  'C:/Users/Marius/Desktop/images\\1445.jpg',
#  'C:/Users/Marius/Desktop/images\\1446.jpg',
#  'C:/Users/Marius/Desktop/images\\1447.jpg',
#  'C:/Users/Marius/Desktop/images\\1448.jpg',
#  'C:/Users/Marius/Desktop/images\\1449.jpg',
#  'C:/Users/Marius/Desktop/images\\145.jpg',
#  'C:/Users/Marius/Desktop/images\\1450.jpg',
#  'C:/Users/Marius/Desktop/images\\1451.jpg',
#  'C:/Users/Marius/Desktop/images\\1452.jpg',
#  'C:/Users/Marius/Desktop/images\\1453.jpg',
#  'C:/Users/Marius/Desktop/images\\1454.jpg',
#  'C:/Users/Marius/Desktop/images\\1455.jpg',
#  'C:/Users/Marius/Desktop/images\\1456.jpg',
#  'C:/Users/Marius/Desktop/images\\1457.jpg',
#  'C:/Users/Marius/Desktop/images\\1458.jpg',
#  'C:/Users/Marius/Desktop/images\\1459.jpg',
#  'C:/Users/Marius/Desktop/images\\146.jpg',
#  'C:/Users/Marius/Desktop/images\\1460.jpg',
#  'C:/Users/Marius/Desktop/images\\1461.jpg',
#  'C:/Users/Marius/Desktop/images\\1462.jpg',
#  'C:/Users/Marius/Desktop/images\\1463.jpg',
#  'C:/Users/Marius/Desktop/images\\1464.jpg',
#  'C:/Users/Marius/Desktop/images\\1465.jpg',
#  'C:/Users/Marius/Desktop/images\\1466.jpg',
#  'C:/Users/Marius/Desktop/images\\1467.jpg',
#  'C:/Users/Marius/Desktop/images\\1468.jpg',
#  'C:/Users/Marius/Desktop/images\\1469.jpg',
#  'C:/Users/Marius/Desktop/images\\147.jpg',
#  'C:/Users/Marius/Desktop/images\\1470.jpg',
#  'C:/Users/Marius/Desktop/images\\1471.jpg',
#  'C:/Users/Marius/Desktop/images\\1472.jpg',
#  'C:/Users/Marius/Desktop/images\\1473.jpg',
#  'C:/Users/Marius/Desktop/images\\1474.jpg',
#  'C:/Users/Marius/Desktop/images\\1475.jpg',
#  'C:/Users/Marius/Desktop/images\\1476.jpg',
#  'C:/Users/Marius/Desktop/images\\1477.jpg',
#  'C:/Users/Marius/Desktop/images\\1478.jpg',
#  'C:/Users/Marius/Desktop/images\\1479.jpg',
#  'C:/Users/Marius/Desktop/images\\148.jpg',
#  'C:/Users/Marius/Desktop/images\\1480.jpg',
#  'C:/Users/Marius/Desktop/images\\1481.jpg',
#  'C:/Users/Marius/Desktop/images\\1482.jpg',
#  'C:/Users/Marius/Desktop/images\\1483.jpg',
#  'C:/Users/Marius/Desktop/images\\1484.jpg',
#  'C:/Users/Marius/Desktop/images\\1485.jpg',
#  'C:/Users/Marius/Desktop/images\\1486.jpg',
#  'C:/Users/Marius/Desktop/images\\1487.jpg',
#  'C:/Users/Marius/Desktop/images\\1488.jpg',
#  'C:/Users/Marius/Desktop/images\\1489.jpg',
#  'C:/Users/Marius/Desktop/images\\149.jpg',
#  'C:/Users/Marius/Desktop/images\\1490.jpg',
#  'C:/Users/Marius/Desktop/images\\1491.jpg',
#  'C:/Users/Marius/Desktop/images\\1492.jpg',
#  'C:/Users/Marius/Desktop/images\\1493.jpg',
#  'C:/Users/Marius/Desktop/images\\1494.jpg',
#  'C:/Users/Marius/Desktop/images\\1495.jpg',
#  'C:/Users/Marius/Desktop/images\\1496.jpg',
#  'C:/Users/Marius/Desktop/images\\1497.jpg',
#  'C:/Users/Marius/Desktop/images\\1498.jpg',
#  'C:/Users/Marius/Desktop/images\\1499.jpg',
#  'C:/Users/Marius/Desktop/images\\15.jpg',
#  'C:/Users/Marius/Desktop/images\\150.jpg',
#  'C:/Users/Marius/Desktop/images\\1500.jpg',
#  'C:/Users/Marius/Desktop/images\\1501.jpg',
#  'C:/Users/Marius/Desktop/images\\1502.jpg',
#  'C:/Users/Marius/Desktop/images\\1503.jpg',
#  'C:/Users/Marius/Desktop/images\\1504.jpg',
#  'C:/Users/Marius/Desktop/images\\1505.jpg',
#  'C:/Users/Marius/Desktop/images\\1506.jpg',
#  'C:/Users/Marius/Desktop/images\\1507.jpg',
#  'C:/Users/Marius/Desktop/images\\1508.jpg',
#  'C:/Users/Marius/Desktop/images\\1509.jpg',
#  'C:/Users/Marius/Desktop/images\\151.jpg',
#  'C:/Users/Marius/Desktop/images\\1510.jpg',
#  'C:/Users/Marius/Desktop/images\\1511.jpg',
#  'C:/Users/Marius/Desktop/images\\1512.jpg',
#  'C:/Users/Marius/Desktop/images\\1513.jpg',
#  'C:/Users/Marius/Desktop/images\\1514.jpg',
#  'C:/Users/Marius/Desktop/images\\1515.jpg',
#  'C:/Users/Marius/Desktop/images\\1516.jpg',
#  'C:/Users/Marius/Desktop/images\\1517.jpg',
#  'C:/Users/Marius/Desktop/images\\1518.jpg',
#  'C:/Users/Marius/Desktop/images\\1519.jpg',
#  'C:/Users/Marius/Desktop/images\\152.jpg',
#  'C:/Users/Marius/Desktop/images\\1520.jpg',
#  'C:/Users/Marius/Desktop/images\\1521.jpg',
#  'C:/Users/Marius/Desktop/images\\1522.jpg',
#  'C:/Users/Marius/Desktop/images\\1523.jpg',
#  'C:/Users/Marius/Desktop/images\\1524.jpg',
#  'C:/Users/Marius/Desktop/images\\1525.jpg',
#  'C:/Users/Marius/Desktop/images\\1526.jpg',
#  'C:/Users/Marius/Desktop/images\\1527.jpg',
#  'C:/Users/Marius/Desktop/images\\1528.jpg',
#  'C:/Users/Marius/Desktop/images\\1529.jpg',
#  'C:/Users/Marius/Desktop/images\\153.jpg',
#  'C:/Users/Marius/Desktop/images\\1530.jpg',
#  'C:/Users/Marius/Desktop/images\\1531.jpg',
#  'C:/Users/Marius/Desktop/images\\1532.jpg',
#  'C:/Users/Marius/Desktop/images\\1533.jpg',
#  'C:/Users/Marius/Desktop/images\\1534.jpg',
#  'C:/Users/Marius/Desktop/images\\1535.jpg',
#  'C:/Users/Marius/Desktop/images\\1536.jpg',
#  'C:/Users/Marius/Desktop/images\\1537.jpg',
#  'C:/Users/Marius/Desktop/images\\1538.jpg',
#  'C:/Users/Marius/Desktop/images\\1539.jpg',
#  'C:/Users/Marius/Desktop/images\\154.jpg',
#  'C:/Users/Marius/Desktop/images\\1540.jpg',
#  'C:/Users/Marius/Desktop/images\\1541.jpg',
#  'C:/Users/Marius/Desktop/images\\1542.jpg',
#  'C:/Users/Marius/Desktop/images\\1543.jpg',
#  'C:/Users/Marius/Desktop/images\\1544.jpg',
#  'C:/Users/Marius/Desktop/images\\1545.jpg',
#  'C:/Users/Marius/Desktop/images\\1546.jpg',
#  'C:/Users/Marius/Desktop/images\\1547.jpg',
#  'C:/Users/Marius/Desktop/images\\1548.jpg',
#  'C:/Users/Marius/Desktop/images\\1549.jpg',
#  'C:/Users/Marius/Desktop/images\\155.jpg',
#  'C:/Users/Marius/Desktop/images\\1550.jpg',
#  'C:/Users/Marius/Desktop/images\\1551.jpg',
#  'C:/Users/Marius/Desktop/images\\1552.jpg',
#  'C:/Users/Marius/Desktop/images\\1553.jpg',
#  'C:/Users/Marius/Desktop/images\\1554.jpg',
#  'C:/Users/Marius/Desktop/images\\1555.jpg',
#  'C:/Users/Marius/Desktop/images\\1556.jpg',
#  'C:/Users/Marius/Desktop/images\\1557.jpg',
#  'C:/Users/Marius/Desktop/images\\1558.jpg',
#  'C:/Users/Marius/Desktop/images\\1559.jpg',
#  'C:/Users/Marius/Desktop/images\\156.jpg',
#  'C:/Users/Marius/Desktop/images\\1560.jpg',
#  'C:/Users/Marius/Desktop/images\\1561.jpg',
#  'C:/Users/Marius/Desktop/images\\1562.jpg',
#  'C:/Users/Marius/Desktop/images\\1563.jpg',
#  'C:/Users/Marius/Desktop/images\\1564.jpg',
#  'C:/Users/Marius/Desktop/images\\1565.jpg',
#  'C:/Users/Marius/Desktop/images\\1566.jpg',
#  'C:/Users/Marius/Desktop/images\\1567.jpg',
#  'C:/Users/Marius/Desktop/images\\1568.jpg',
#  'C:/Users/Marius/Desktop/images\\1569.jpg',
#  'C:/Users/Marius/Desktop/images\\157.jpg',
#  'C:/Users/Marius/Desktop/images\\1570.jpg',
#  'C:/Users/Marius/Desktop/images\\1571.jpg',
#  'C:/Users/Marius/Desktop/images\\1572.jpg',
#  'C:/Users/Marius/Desktop/images\\1573.jpg',
#  'C:/Users/Marius/Desktop/images\\1574.jpg',
#  'C:/Users/Marius/Desktop/images\\1575.jpg',
#  'C:/Users/Marius/Desktop/images\\1576.jpg',
#  'C:/Users/Marius/Desktop/images\\1577.jpg',
#  'C:/Users/Marius/Desktop/images\\1578.jpg',
#  'C:/Users/Marius/Desktop/images\\1579.jpg',
#  'C:/Users/Marius/Desktop/images\\158.jpg',
#  'C:/Users/Marius/Desktop/images\\1580.jpg',
#  'C:/Users/Marius/Desktop/images\\1581.jpg',
#  'C:/Users/Marius/Desktop/images\\1582.jpg',
#  'C:/Users/Marius/Desktop/images\\1583.jpg',
#  'C:/Users/Marius/Desktop/images\\1584.jpg',
#  'C:/Users/Marius/Desktop/images\\159.jpg',
#  'C:/Users/Marius/Desktop/images\\16.jpg',
#  'C:/Users/Marius/Desktop/images\\160.jpg',
#  'C:/Users/Marius/Desktop/images\\161.jpg',
#  'C:/Users/Marius/Desktop/images\\162.jpg',
#  'C:/Users/Marius/Desktop/images\\163.jpg',
#  'C:/Users/Marius/Desktop/images\\164.jpg',
#  'C:/Users/Marius/Desktop/images\\165.jpg',
#  'C:/Users/Marius/Desktop/images\\166.jpg',
#  'C:/Users/Marius/Desktop/images\\167.jpg',
#  'C:/Users/Marius/Desktop/images\\168.jpg',
#  'C:/Users/Marius/Desktop/images\\169.jpg',
#  'C:/Users/Marius/Desktop/images\\17.jpg',
#  'C:/Users/Marius/Desktop/images\\170.jpg',
#  'C:/Users/Marius/Desktop/images\\171.jpg',
#  'C:/Users/Marius/Desktop/images\\172.jpg',
#  'C:/Users/Marius/Desktop/images\\173.jpg',
#  'C:/Users/Marius/Desktop/images\\174.jpg',
#  'C:/Users/Marius/Desktop/images\\175.jpg',
#  'C:/Users/Marius/Desktop/images\\176.jpg',
#  'C:/Users/Marius/Desktop/images\\177.jpg',
#  'C:/Users/Marius/Desktop/images\\178.jpg',
#  'C:/Users/Marius/Desktop/images\\179.jpg',
#  'C:/Users/Marius/Desktop/images\\18.jpg',
#  'C:/Users/Marius/Desktop/images\\180.jpg',
#  'C:/Users/Marius/Desktop/images\\181.jpg',
#  'C:/Users/Marius/Desktop/images\\182.jpg',
#  'C:/Users/Marius/Desktop/images\\183.jpg',
#  'C:/Users/Marius/Desktop/images\\184.jpg',
#  'C:/Users/Marius/Desktop/images\\185.jpg',
#  'C:/Users/Marius/Desktop/images\\186.jpg',
#  'C:/Users/Marius/Desktop/images\\187.jpg',
#  'C:/Users/Marius/Desktop/images\\188.jpg',
#  'C:/Users/Marius/Desktop/images\\189.jpg',
#  'C:/Users/Marius/Desktop/images\\19.jpg',
#  'C:/Users/Marius/Desktop/images\\190.jpg',
#  'C:/Users/Marius/Desktop/images\\191.jpg',
#  'C:/Users/Marius/Desktop/images\\192.jpg',
#  'C:/Users/Marius/Desktop/images\\193.jpg',
#  'C:/Users/Marius/Desktop/images\\194.jpg',
#  'C:/Users/Marius/Desktop/images\\195.jpg',
#  'C:/Users/Marius/Desktop/images\\196.jpg',
#  'C:/Users/Marius/Desktop/images\\197.jpg',
#  'C:/Users/Marius/Desktop/images\\198.jpg',
#  'C:/Users/Marius/Desktop/images\\199.jpg',
#  'C:/Users/Marius/Desktop/images\\2.jpg',
#  'C:/Users/Marius/Desktop/images\\20.jpg',
#  'C:/Users/Marius/Desktop/images\\200.jpg',
#  'C:/Users/Marius/Desktop/images\\201.jpg',
#  'C:/Users/Marius/Desktop/images\\202.jpg',
#  'C:/Users/Marius/Desktop/images\\203.jpg',
#  'C:/Users/Marius/Desktop/images\\204.jpg',
#  'C:/Users/Marius/Desktop/images\\205.jpg',
#  'C:/Users/Marius/Desktop/images\\206.jpg',
#  'C:/Users/Marius/Desktop/images\\207.jpg',
#  'C:/Users/Marius/Desktop/images\\208.jpg',
#  'C:/Users/Marius/Desktop/images\\209.jpg',
#  'C:/Users/Marius/Desktop/images\\21.jpg',
#  'C:/Users/Marius/Desktop/images\\210.jpg',
#  'C:/Users/Marius/Desktop/images\\211.jpg',
#  'C:/Users/Marius/Desktop/images\\212.jpg',
#  'C:/Users/Marius/Desktop/images\\213.jpg',
#  'C:/Users/Marius/Desktop/images\\214.jpg',
#  'C:/Users/Marius/Desktop/images\\215.jpg',
#  'C:/Users/Marius/Desktop/images\\216.jpg',
#  'C:/Users/Marius/Desktop/images\\217.jpg',
#  'C:/Users/Marius/Desktop/images\\218.jpg',
#  'C:/Users/Marius/Desktop/images\\219.jpg',
#  'C:/Users/Marius/Desktop/images\\22.jpg',
#  'C:/Users/Marius/Desktop/images\\220.jpg',
#  'C:/Users/Marius/Desktop/images\\221.jpg',
#  'C:/Users/Marius/Desktop/images\\222.jpg',
#  'C:/Users/Marius/Desktop/images\\223.jpg',
#  'C:/Users/Marius/Desktop/images\\224.jpg',
#  'C:/Users/Marius/Desktop/images\\225.jpg',
#  'C:/Users/Marius/Desktop/images\\226.jpg',
#  'C:/Users/Marius/Desktop/images\\227.jpg',
#  'C:/Users/Marius/Desktop/images\\228.jpg',
#  'C:/Users/Marius/Desktop/images\\229.jpg',
#  'C:/Users/Marius/Desktop/images\\23.jpg',
#  'C:/Users/Marius/Desktop/images\\230.jpg',
#  'C:/Users/Marius/Desktop/images\\231.jpg',
#  'C:/Users/Marius/Desktop/images\\232.jpg',
#  'C:/Users/Marius/Desktop/images\\233.jpg',
#  'C:/Users/Marius/Desktop/images\\234.jpg',
#  'C:/Users/Marius/Desktop/images\\235.jpg',
#  'C:/Users/Marius/Desktop/images\\236.jpg',
#  'C:/Users/Marius/Desktop/images\\237.jpg',
#  'C:/Users/Marius/Desktop/images\\238.jpg',
#  'C:/Users/Marius/Desktop/images\\239.jpg',
#  'C:/Users/Marius/Desktop/images\\24.jpg',
#  'C:/Users/Marius/Desktop/images\\240.jpg',
#  'C:/Users/Marius/Desktop/images\\241.jpg',
#  'C:/Users/Marius/Desktop/images\\242.jpg',
#  'C:/Users/Marius/Desktop/images\\243.jpg',
#  'C:/Users/Marius/Desktop/images\\244.jpg',
#  'C:/Users/Marius/Desktop/images\\245.jpg',
#  'C:/Users/Marius/Desktop/images\\246.jpg',
#  'C:/Users/Marius/Desktop/images\\247.jpg',
#  'C:/Users/Marius/Desktop/images\\248.jpg',
#  'C:/Users/Marius/Desktop/images\\249.jpg',
#  'C:/Users/Marius/Desktop/images\\25.jpg',
#  'C:/Users/Marius/Desktop/images\\250.jpg',
#  'C:/Users/Marius/Desktop/images\\251.jpg',
#  'C:/Users/Marius/Desktop/images\\252.jpg',
#  'C:/Users/Marius/Desktop/images\\253.jpg',
#  'C:/Users/Marius/Desktop/images\\254.jpg',
#  'C:/Users/Marius/Desktop/images\\255.jpg',
#  'C:/Users/Marius/Desktop/images\\256.jpg',
#  'C:/Users/Marius/Desktop/images\\257.jpg',
#  'C:/Users/Marius/Desktop/images\\258.jpg',
#  'C:/Users/Marius/Desktop/images\\259.jpg',
#  'C:/Users/Marius/Desktop/images\\26.jpg',
#  'C:/Users/Marius/Desktop/images\\260.jpg',
#  'C:/Users/Marius/Desktop/images\\261.jpg',
#  'C:/Users/Marius/Desktop/images\\262.jpg',
#  'C:/Users/Marius/Desktop/images\\263.jpg',
#  'C:/Users/Marius/Desktop/images\\264.jpg',
#  'C:/Users/Marius/Desktop/images\\265.jpg',
#  'C:/Users/Marius/Desktop/images\\266.jpg',
#  'C:/Users/Marius/Desktop/images\\267.jpg',
#  'C:/Users/Marius/Desktop/images\\268.jpg',
#  'C:/Users/Marius/Desktop/images\\269.jpg',
#  'C:/Users/Marius/Desktop/images\\27.jpg',
#  'C:/Users/Marius/Desktop/images\\270.jpg',
#  'C:/Users/Marius/Desktop/images\\271.jpg',
#  'C:/Users/Marius/Desktop/images\\272.jpg',
#  'C:/Users/Marius/Desktop/images\\273.jpg',
#  'C:/Users/Marius/Desktop/images\\274.jpg',
#  'C:/Users/Marius/Desktop/images\\275.jpg',
#  'C:/Users/Marius/Desktop/images\\276.jpg',
#  'C:/Users/Marius/Desktop/images\\277.jpg',
#  'C:/Users/Marius/Desktop/images\\278.jpg',
#  'C:/Users/Marius/Desktop/images\\279.jpg',
#  'C:/Users/Marius/Desktop/images\\28.jpg',
#  'C:/Users/Marius/Desktop/images\\280.jpg',
#  'C:/Users/Marius/Desktop/images\\281.jpg',
#  'C:/Users/Marius/Desktop/images\\282.jpg',
#  'C:/Users/Marius/Desktop/images\\283.jpg',
#  'C:/Users/Marius/Desktop/images\\284.jpg',
#  'C:/Users/Marius/Desktop/images\\285.jpg',
#  'C:/Users/Marius/Desktop/images\\286.jpg',
#  'C:/Users/Marius/Desktop/images\\287.jpg',
#  'C:/Users/Marius/Desktop/images\\288.jpg',
#  'C:/Users/Marius/Desktop/images\\289.jpg',
#  'C:/Users/Marius/Desktop/images\\29.jpg',
#  'C:/Users/Marius/Desktop/images\\290.jpg',
#  'C:/Users/Marius/Desktop/images\\291.jpg',
#  'C:/Users/Marius/Desktop/images\\292.jpg',
#  'C:/Users/Marius/Desktop/images\\293.jpg',
#  'C:/Users/Marius/Desktop/images\\294.jpg',
#  'C:/Users/Marius/Desktop/images\\295.jpg',
#  'C:/Users/Marius/Desktop/images\\296.jpg',
#  'C:/Users/Marius/Desktop/images\\297.jpg',
#  'C:/Users/Marius/Desktop/images\\298.jpg',
#  'C:/Users/Marius/Desktop/images\\299.jpg',
#  'C:/Users/Marius/Desktop/images\\3.jpg',
#  'C:/Users/Marius/Desktop/images\\30.jpg',
#  'C:/Users/Marius/Desktop/images\\300.jpg',
#  'C:/Users/Marius/Desktop/images\\301.jpg',
#  'C:/Users/Marius/Desktop/images\\302.jpg',
#  'C:/Users/Marius/Desktop/images\\303.jpg',
#  'C:/Users/Marius/Desktop/images\\304.jpg',
#  'C:/Users/Marius/Desktop/images\\305.jpg',
#  'C:/Users/Marius/Desktop/images\\306.jpg',
#  'C:/Users/Marius/Desktop/images\\307.jpg',
#  'C:/Users/Marius/Desktop/images\\308.jpg',
#  'C:/Users/Marius/Desktop/images\\309.jpg',
#  'C:/Users/Marius/Desktop/images\\31.jpg',
#  'C:/Users/Marius/Desktop/images\\310.jpg',
#  'C:/Users/Marius/Desktop/images\\311.jpg',
#  'C:/Users/Marius/Desktop/images\\312.jpg',
#  'C:/Users/Marius/Desktop/images\\313.jpg',
#  'C:/Users/Marius/Desktop/images\\314.jpg',
#  'C:/Users/Marius/Desktop/images\\315.jpg',
#  'C:/Users/Marius/Desktop/images\\316.jpg',
#  'C:/Users/Marius/Desktop/images\\317.jpg',
#  'C:/Users/Marius/Desktop/images\\318.jpg',
#  'C:/Users/Marius/Desktop/images\\319.jpg',
#  'C:/Users/Marius/Desktop/images\\32.jpg',
#  'C:/Users/Marius/Desktop/images\\320.jpg',
#  'C:/Users/Marius/Desktop/images\\321.jpg',
#  'C:/Users/Marius/Desktop/images\\322.jpg',
#  'C:/Users/Marius/Desktop/images\\323.jpg',
#  'C:/Users/Marius/Desktop/images\\324.jpg',
#  'C:/Users/Marius/Desktop/images\\325.jpg',
#  'C:/Users/Marius/Desktop/images\\326.jpg',
#  'C:/Users/Marius/Desktop/images\\327.jpg',
#  'C:/Users/Marius/Desktop/images\\328.jpg',
#  'C:/Users/Marius/Desktop/images\\329.jpg',
#  'C:/Users/Marius/Desktop/images\\33.jpg',
#  'C:/Users/Marius/Desktop/images\\330.jpg',
#  'C:/Users/Marius/Desktop/images\\331.jpg',
#  'C:/Users/Marius/Desktop/images\\332.jpg',
#  'C:/Users/Marius/Desktop/images\\333.jpg',
#  'C:/Users/Marius/Desktop/images\\334.jpg',
#  'C:/Users/Marius/Desktop/images\\335.jpg',
#  'C:/Users/Marius/Desktop/images\\336.jpg',
#  'C:/Users/Marius/Desktop/images\\337.jpg',
#  'C:/Users/Marius/Desktop/images\\338.jpg',
#  'C:/Users/Marius/Desktop/images\\339.jpg',
#  'C:/Users/Marius/Desktop/images\\34.jpg',
#  'C:/Users/Marius/Desktop/images\\340.jpg',
#  'C:/Users/Marius/Desktop/images\\341.jpg',
#  'C:/Users/Marius/Desktop/images\\342.jpg',
#  'C:/Users/Marius/Desktop/images\\343.jpg',
#  'C:/Users/Marius/Desktop/images\\344.jpg',
#  'C:/Users/Marius/Desktop/images\\345.jpg',
#  'C:/Users/Marius/Desktop/images\\346.jpg',
#  'C:/Users/Marius/Desktop/images\\347.jpg',
#  'C:/Users/Marius/Desktop/images\\348.jpg',
#  'C:/Users/Marius/Desktop/images\\349.jpg',
#  'C:/Users/Marius/Desktop/images\\35.jpg',
#  'C:/Users/Marius/Desktop/images\\350.jpg',
#  'C:/Users/Marius/Desktop/images\\351.jpg',
#  'C:/Users/Marius/Desktop/images\\352.jpg',
#  'C:/Users/Marius/Desktop/images\\353.jpg',
#  'C:/Users/Marius/Desktop/images\\354.jpg',
#  'C:/Users/Marius/Desktop/images\\355.jpg',
#  'C:/Users/Marius/Desktop/images\\356.jpg',
#  'C:/Users/Marius/Desktop/images\\357.jpg',
#  'C:/Users/Marius/Desktop/images\\358.jpg',
#  'C:/Users/Marius/Desktop/images\\359.jpg',
#  'C:/Users/Marius/Desktop/images\\36.jpg',
#  'C:/Users/Marius/Desktop/images\\360.jpg',
#  'C:/Users/Marius/Desktop/images\\361.jpg',
#  'C:/Users/Marius/Desktop/images\\362.jpg',
#  'C:/Users/Marius/Desktop/images\\363.jpg',
#  'C:/Users/Marius/Desktop/images\\364.jpg',
#  'C:/Users/Marius/Desktop/images\\365.jpg',
#  'C:/Users/Marius/Desktop/images\\366.jpg',
#  'C:/Users/Marius/Desktop/images\\367.jpg',
#  'C:/Users/Marius/Desktop/images\\368.jpg',
#  'C:/Users/Marius/Desktop/images\\369.jpg',
#  'C:/Users/Marius/Desktop/images\\37.jpg',
#  'C:/Users/Marius/Desktop/images\\370.jpg',
#  'C:/Users/Marius/Desktop/images\\371.jpg',
#  'C:/Users/Marius/Desktop/images\\372.jpg',
#  'C:/Users/Marius/Desktop/images\\373.jpg',
#  'C:/Users/Marius/Desktop/images\\374.jpg',
#  'C:/Users/Marius/Desktop/images\\375.jpg',
#  'C:/Users/Marius/Desktop/images\\376.jpg',
#  'C:/Users/Marius/Desktop/images\\377.jpg',
#  'C:/Users/Marius/Desktop/images\\378.jpg',
#  'C:/Users/Marius/Desktop/images\\379.jpg',
#  'C:/Users/Marius/Desktop/images\\38.jpg',
#  'C:/Users/Marius/Desktop/images\\380.jpg',
#  'C:/Users/Marius/Desktop/images\\381.jpg',
#  'C:/Users/Marius/Desktop/images\\382.jpg',
#  'C:/Users/Marius/Desktop/images\\383.jpg',
#  'C:/Users/Marius/Desktop/images\\384.jpg',
#  'C:/Users/Marius/Desktop/images\\385.jpg',
#  'C:/Users/Marius/Desktop/images\\386.jpg',
#  'C:/Users/Marius/Desktop/images\\387.jpg',
#  'C:/Users/Marius/Desktop/images\\388.jpg',
#  'C:/Users/Marius/Desktop/images\\389.jpg',
#  'C:/Users/Marius/Desktop/images\\39.jpg',
#  'C:/Users/Marius/Desktop/images\\390.jpg',
#  'C:/Users/Marius/Desktop/images\\391.jpg',
#  'C:/Users/Marius/Desktop/images\\392.jpg',
#  'C:/Users/Marius/Desktop/images\\393.jpg',
#  'C:/Users/Marius/Desktop/images\\394.jpg',
#  'C:/Users/Marius/Desktop/images\\395.jpg',
#  'C:/Users/Marius/Desktop/images\\396.jpg',
#  'C:/Users/Marius/Desktop/images\\397.jpg',
#  'C:/Users/Marius/Desktop/images\\398.jpg',
#  'C:/Users/Marius/Desktop/images\\399.jpg',
#  'C:/Users/Marius/Desktop/images\\4.jpg',
#  'C:/Users/Marius/Desktop/images\\40.jpg',
#  'C:/Users/Marius/Desktop/images\\400.jpg',
#  'C:/Users/Marius/Desktop/images\\401.jpg',
#  'C:/Users/Marius/Desktop/images\\402.jpg',
#  'C:/Users/Marius/Desktop/images\\403.jpg',
#  'C:/Users/Marius/Desktop/images\\404.jpg',
#  'C:/Users/Marius/Desktop/images\\405.jpg',
#  'C:/Users/Marius/Desktop/images\\406.jpg',
#  'C:/Users/Marius/Desktop/images\\407.jpg',
#  'C:/Users/Marius/Desktop/images\\408.jpg',
#  'C:/Users/Marius/Desktop/images\\409.jpg',
#  'C:/Users/Marius/Desktop/images\\41.jpg',
#  'C:/Users/Marius/Desktop/images\\410.jpg',
#  'C:/Users/Marius/Desktop/images\\411.jpg',
#  'C:/Users/Marius/Desktop/images\\412.jpg',
#  'C:/Users/Marius/Desktop/images\\413.jpg',
#  'C:/Users/Marius/Desktop/images\\414.jpg',
#  'C:/Users/Marius/Desktop/images\\415.jpg',
#  'C:/Users/Marius/Desktop/images\\416.jpg',
#  'C:/Users/Marius/Desktop/images\\417.jpg',
#  'C:/Users/Marius/Desktop/images\\418.jpg',
#  'C:/Users/Marius/Desktop/images\\419.jpg',
#  'C:/Users/Marius/Desktop/images\\42.jpg',
#  'C:/Users/Marius/Desktop/images\\420.jpg',
#  'C:/Users/Marius/Desktop/images\\421.jpg',
#  'C:/Users/Marius/Desktop/images\\422.jpg',
#  'C:/Users/Marius/Desktop/images\\423.jpg',
#  'C:/Users/Marius/Desktop/images\\424.jpg',
#  'C:/Users/Marius/Desktop/images\\425.jpg',
#  'C:/Users/Marius/Desktop/images\\426.jpg',
#  'C:/Users/Marius/Desktop/images\\427.jpg',
#  'C:/Users/Marius/Desktop/images\\428.jpg',
#  'C:/Users/Marius/Desktop/images\\429.jpg',
#  'C:/Users/Marius/Desktop/images\\43.jpg',
#  'C:/Users/Marius/Desktop/images\\430.jpg',
#  'C:/Users/Marius/Desktop/images\\431.jpg',
#  'C:/Users/Marius/Desktop/images\\432.jpg',
#  'C:/Users/Marius/Desktop/images\\433.jpg',
#  'C:/Users/Marius/Desktop/images\\434.jpg',
#  'C:/Users/Marius/Desktop/images\\435.jpg',
#  'C:/Users/Marius/Desktop/images\\436.jpg',
#  'C:/Users/Marius/Desktop/images\\437.jpg',
#  'C:/Users/Marius/Desktop/images\\438.jpg',
#  'C:/Users/Marius/Desktop/images\\439.jpg',
#  'C:/Users/Marius/Desktop/images\\44.jpg',
#  'C:/Users/Marius/Desktop/images\\440.jpg',
#  'C:/Users/Marius/Desktop/images\\441.jpg',
#  'C:/Users/Marius/Desktop/images\\442.jpg',
#  'C:/Users/Marius/Desktop/images\\443.jpg',
#  'C:/Users/Marius/Desktop/images\\444.jpg',
#  'C:/Users/Marius/Desktop/images\\445.jpg',
#  'C:/Users/Marius/Desktop/images\\446.jpg',
#  'C:/Users/Marius/Desktop/images\\447.jpg',
#  'C:/Users/Marius/Desktop/images\\448.jpg',
#  'C:/Users/Marius/Desktop/images\\449.jpg',
#  'C:/Users/Marius/Desktop/images\\45.jpg',
#  'C:/Users/Marius/Desktop/images\\450.jpg',
#  'C:/Users/Marius/Desktop/images\\451.jpg',
#  'C:/Users/Marius/Desktop/images\\452.jpg',
#  'C:/Users/Marius/Desktop/images\\453.jpg',
#  'C:/Users/Marius/Desktop/images\\454.jpg',
#  'C:/Users/Marius/Desktop/images\\455.jpg',
#  'C:/Users/Marius/Desktop/images\\456.jpg',
#  'C:/Users/Marius/Desktop/images\\457.jpg',
#  'C:/Users/Marius/Desktop/images\\458.jpg',
#  'C:/Users/Marius/Desktop/images\\459.jpg',
#  'C:/Users/Marius/Desktop/images\\46.jpg',
#  'C:/Users/Marius/Desktop/images\\460.jpg',
#  'C:/Users/Marius/Desktop/images\\461.jpg',
#  'C:/Users/Marius/Desktop/images\\462.jpg',
#  'C:/Users/Marius/Desktop/images\\463.jpg',
#  'C:/Users/Marius/Desktop/images\\464.jpg',
#  'C:/Users/Marius/Desktop/images\\465.jpg',
#  'C:/Users/Marius/Desktop/images\\466.jpg',
#  'C:/Users/Marius/Desktop/images\\467.jpg',
#  'C:/Users/Marius/Desktop/images\\468.jpg',
#  'C:/Users/Marius/Desktop/images\\469.jpg',
#  'C:/Users/Marius/Desktop/images\\47.jpg',
#  'C:/Users/Marius/Desktop/images\\470.jpg',
#  'C:/Users/Marius/Desktop/images\\471.jpg',
#  'C:/Users/Marius/Desktop/images\\472.jpg',
#  ...]

# %%
fig = plt.figure(figsize = (20,20))
rows = 11
columns = 9
axes = []

for i in range(99):
    img = imread(image_paths[i], as_gray = True) 
    axes.append(fig.add_subplot(rows,columns,i+1))
    plt.imshow(img, cmap = 'gray')
    plt.title("%s" % (species[i]))
    plt.axis('off')

fig.tight_layout()
plt.show()

# %% [markdown]
# As you can see, classifying leaves is actually a very tough problem.
# What makes it even worse, is that we cannot use all the image data we have available.
# In order to decrease the amount of computations needed, we need to reduce the size of the images as much as possible.
# On top of that our neural network usually only accepts fixed size input tensors.
# This means we will have to change the shape of the images so that they all have the same sizes.
#
#
# Resizing is problematic because it alters the shape of the leaves, and for some of them, this is their most distinctive feature. Take a look at `Salix_Intergra` in the bottom left corner.
# Describing this leaf without taking its' shape into account seems extremely difficult.
#
# Therefore we will
# - 1) first pad all the images into squares, and
# - 2) then resize them, as visualized below:

# %% [markdown]
# ## Exercise 3
#
# 3.1) **Find an appropriate image size**. Test various resizings of the image until you have found the smallest resizing of the image where you "can still differentiate between the images".
# How small is to small should ultimately be determined by an actual test, but what makes visual sense is a good place to start.
# Change the `image_size=(?, ?)` parameter below, and note your choice.
#  * **Answer:**

# %%
## Image pre-processing
image_size = (40, 40)  # <-- YOUR CODE HERE

# Amount of images
amount = 5
image_sample = np.random.choice(train_images, amount)

# Define figure size
fig = plt.figure(figsize=(18, 6))

# Save original images in the figure
ax = plt.subplot(2, amount + 1, 1)
txt = ax.text(0.4, 0.5, 'Original', fontsize=20)
txt.set_clip_on(False)
plt.axis('off')
for i, path in enumerate(image_sample):
    plt.subplot(2, amount + 1, i + 2)
    image = imread(path, as_gray=True)    
    plt.imshow(image, cmap='gray')
    _id = int(path.split('/')[-1].split('.')[0])
    plt.title("{0}\nshape: {1}".format(train[train.id == _id].species.values[0], image.shape))
    plt.axis('off')
    
# Save resized images in the figure
ax = plt.subplot(2, amount + 1, len(image_sample) + 2)
txt = ax.text(0.4, 0.5, 'Resized', fontsize=20)
txt.set_clip_on(False)
plt.axis('off')
for i, path in enumerate(image_sample):
    i += len(image_sample) + 3
    plt.subplot(2, amount + 1, i)
    image = imread(path, as_gray=True)
    image = data_utils.pad2square(image)  # Make the image square
    image = resize(image, output_shape=image_size, mode='reflect', anti_aliasing=True)  # resizes the image
    plt.imshow(image, cmap='gray')

# Show plot
plt.show()

# %% [markdown]
# ## Investigating the other features
#
# Now that we have looked at the image data we have available, it is time to take a look at the other available features. Below we choose a random subset of the training data, and visualize the 3 types of available features:
# * margin
# * shape
# * texture
#
# Try to run it a few times to try and get an understanding of how the features differ from species to species.

# %%
# Extract features
X = train.values
species = X[:, 1:2]
margin = X[:, 2:66]
shape = X[:, 66:130]
texture = X[:, 130:]

# Let us plot some of the features
plt.figure(figsize=(21,7)) # Set the plot size
amount = 5                 # Choose the amount of images we want to show at a time

for i, idx in enumerate(np.random.choice(range(len(train)), amount)):
    ax = plt.subplot(amount,4,1+i*4)
    txt = ax.text(0.2, 0.2, species[idx][0], fontsize=20)
    txt.set_clip_on(False)
    plt.axis('off')
    if i == 0:
        plt.title('Species', fontsize=20)
    plt.subplot(amount,4,2+i*4)
    plt.plot(margin[idx])
    if i == 0:
        plt.title('Margin', fontsize=20)
    plt.axis('off')
    plt.subplot(amount,4,3+i*4)
    plt.plot(shape[idx])
    if i == 0:
        plt.title('Shape', fontsize=20)
    plt.axis('off')
    plt.subplot(amount,4,4+i*4)
    plt.plot(texture[idx])
    if i == 0:
        plt.title('Texture', fontsize=20)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 4
# So far we have learned about the feed forward neural network (FFNN), the convolutional neural network (CNN) and the recurrent neural network (RNN).
#
# 4.1) How could the `image`, `Margin`, `Shape` and `Texture` be used for classification, i.e. what kind of network type would you use for each of them, and why?
#  * **Answer:**
#
#  - Image: Convolutional Neural network, very good for image recognition in general.
#  - Margin, Shape, Texture: Recurrent neural networks because they are good for sequence prediction tasks.

# %% [markdown]
# # Managing the data
#
# The details of the code in this section isn't that important.
# It simply manages the data in a nice way - so it is a good place to come back and look for inspiration when you going to work on your own projects.
#
#
# ## Defining the data loader

# %% [markdown]
# ## Exercise 5
# 5.1) As a part of the data loader, we should specify the shape of the images, number of classes, and the number of features for the three feature types: margin, shape and texture. Define the three variables in the code below.

# %%
# The image shape should be of the format (height, width, channels)
IMAGE_SHAPE =    (40,40,1)
NUM_CLASSES =    99

# For all three features types margin, shape, and texture, we have NUM_FEATURES for each type.
NUM_FEATURES =   64

# %%
# Paths to data
TRAIN_PATH = local_path + "train.csv" 
TEST_PATH = local_path + "test.csv" 
IMAGE_PATHS = glob.glob(local_path + "images/*.jpg")

# train holds both X (input) and t (target/truth)
data = data_utils.load_data(train_path=TRAIN_PATH, 
                            test_path=TEST_PATH,
                            image_paths=IMAGE_PATHS,
                            image_shape=IMAGE_SHAPE[:2])
# to visualize the size of the dimensions of the data
print("\n@@@Shape checking of data sets@@@")
print("TRAIN")
print("\timages\t%s%f" % (data.train['images'].shape, data.train['images'].mean()))
print("\tmargins\t%s\t%f" % (data.train['margins'].shape, data.train['margins'].mean()))
print("\tshapes\t%s\t%f" % (data.train['shapes'].shape, data.train['shapes'].mean()))
print("\ttextures%s\t%f" % (data.train['textures'].shape, data.train['textures'].mean()))
print("\tts\t %s" % (data.train['ts'].shape))
print("\twhile training, batch_generator will onehot encode ts to (batch_size, num_classes)")
print("TEST")
print("\timages\t%s\t%f" % (data.test['images'].shape, data.test['images'].mean())) 
print("\tmargins\t%s\t%f" % (data.test['margins'].shape, data.test['margins'].mean()))
print("\tshapes\t%s\t%f" % (data.test['shapes'].shape, data.test['shapes'].mean()))
print("\ttextures%s\t%f" % (data.test['textures'].shape, data.test['textures'].mean()))
print("\tids\t%s" % (data.test['ids'].shape))
# Out:
# Loading training data
# 	0 of 990
# 	100 of 990
# 	200 of 990
# 	300 of 990
# 	400 of 990
# 	500 of 990
# 	600 of 990
# 	700 of 990
# 	800 of 990
# 	900 of 990
# Loading test data
# 	0 of 594
# 	100 of 594
# 	200 of 594
# 	300 of 594
# 	400 of 594
# 	500 of 594
#
# @@@Shape checking of data sets@@@
# TRAIN
# 	images	(990, 40, 40, 1)0.279976
# 	margins	(990, 64)	0.015625
# 	shapes	(990, 64)	0.000607
# 	textures(990, 64)	0.015625
# 	ts	 990
# 	while training, batch_generator will onehot encode ts to (batch_size, num_classes)
# TEST
# 	images	(594, 40, 40, 1)	0.280263
# 	margins	(594, 64)	0.015625
# 	shapes	(594, 64)	0.000604
# 	textures(594, 64)	0.015625
# 	ids	594

# %% [markdown]
# #### Do you want to load your data quickly next time?
# In the above cell the data is loaded, reshaped and stored as an object. If you want load this object quickly next time you should go for pickle. Pickle does effectively write an object into a character stream, so it can be loaded fastly next time. Simply replace `drive_path` with you `local_path` if you're not using colab.

# %%
# import pickle

# # Dump the data into a pickle file
# with open(drive_path + '/data.pickle', 'wb') as f:
#     pickle.dump(data, f)

# %%
# # Load the data from a pickle file
# with open(drive_path + '/data.pickle', 'rb') as f:
#     data = pickle.load(f)

# %% [markdown]
# ## Batch Generator
#
# While training, we will not directly access the entire dataset, instead we have a `batch_generator` function to give us inputs aligned with their targets/ids in a size that our model can handle in memory (batch\_size).
#
# Furthermore, the `batch_generator` also handles validation splitting.
#
# ## Exercise 6
# 6.1) Explain shortly why the size of batches is important. You should comment on how the size of batches affect the memory, training speed, and the estimates of the gradients.
# Choose a reasonable batch size the `batch_size = ?` parameter below, and note your choice.
#
#  * **Answer:**
#
# Large batch sizes may cause bad generalization, i.e. overfitting or even cause the model to get stuck in a local minima. On the other hand small batches may result in a slower convergence of the algorithm. That is because the fewer samples we have, the less accurate the gradient estimates will be, but they will happen faster. Gradient descent will need to go through a full training set normally before taking a small gradient descent step. With batching this gradient descent step can be taken much faster, after seeing just a fraction (a batch) of the data.
#
# Also large batch sizes usually mean that the model will go through a full epoch faster, and thus learn faster, if the memory is capable of processing the large batches. Fx: if we use vectorization for our data, for a batch size of 100 the computer might not be able to process all 100 images at once.

# %%
batch_size = 90 # in order to have exactly 11 batches
dummy_batch_gen = data_utils.batch_generator(data, batch_size=batch_size, num_classes=NUM_CLASSES, num_iterations=5e3, seed=42)
train_batch = next(dummy_batch_gen.gen_train())
valid_batch, i = next(dummy_batch_gen.gen_valid())
test_batch, i = next(dummy_batch_gen.gen_test())

print("TRAIN")
print("\timages,", train_batch['images'].shape)
print("\tmargins,", train_batch['margins'].shape)
print("\tshapes,", train_batch['shapes'].shape)
print("\ttextures,", train_batch['textures'].shape)
print("\tts,", train_batch['ts'].shape)
print()
print("VALID")
print("\timages,", valid_batch['images'].shape)
print("\tmargins,", valid_batch['margins'].shape)
print("\tshapes,", valid_batch['shapes'].shape)
print("\ttextures,", valid_batch['textures'].shape)
print("\tts,", valid_batch['ts'].shape)
print()
print("TEST")
print("\timages,", test_batch['images'].shape)
print("\tmargins,", test_batch['margins'].shape)
print("\tshapes,", test_batch['shapes'].shape)
print("\ttextures,", test_batch['textures'].shape)
print("\tids,", len(test_batch['ids']))
# Out:
# TRAIN
# 	images, (90, 40, 40, 1)
# 	margins, (90, 64)
# 	shapes, (90, 64)
# 	textures, (90, 64)
# 	ts, (90, 99)
#
# VALID
# 	images, (90, 40, 40, 1)
# 	margins, (90, 64)
# 	shapes, (90, 64)
# 	textures, (90, 64)
# 	ts, (90, 99)
#
# TEST
# 	images, (90, 40, 40, 1)
# 	margins, (90, 64)
# 	shapes, (90, 64)
# 	textures, (90, 64)
# 	ids, 90

# %% [markdown]
# # Build the model

# %%
# Load functions
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
from torch.nn import Linear, GRU, Conv2d, Dropout, MaxPool2d, BatchNorm1d
from torch.nn.functional import relu, elu, relu6, sigmoid, tanh, softmax

# %%
use_cuda = torch.cuda.is_available()
print("Running GPU.") if use_cuda else print("No GPU available.")


def get_variable(x):
    """ Converts tensors to cuda, if available. """
    if use_cuda:
        return x.cuda()
    return x


def get_numpy(x):
    """ Get numpy array for both cuda and not. """
    if use_cuda:
        return x.cpu().data.numpy()
    return x.data.numpy()
# Out:
# Running GPU.

# %% [markdown]
# ## Exercise 7
# 7.1)  Now you must define the network architecture. It is always a good idea to start simple. We recommend you to start with a mix of a convolutional layer (maybe followed by max pooling layer), a recurrent layer, and a linear output layer such that we use all the features.
#
# When you build the model you should be aware of the dimensions of the input and output for your different layers. The function`permute` and `view` will be very useful to rearrange your dimensions. It might also be useful to look up the helper function for computing convolutional layers' dimensions from lab 4.1.

# %%
height, width, channels = IMAGE_SHAPE

conv_out_channels =  10
kernel_size =        (5,5)
conv_stride =        1
conv_pad    =        0
 
# Keep track of features to output layer
features_cat_size = 192
    
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv_1 = Conv2d(in_channels=channels,
                             out_channels=conv_out_channels,
                             kernel_size=kernel_size,
                             stride=conv_stride,
                             padding=conv_pad)
        
        self.pool = nn.MaxPool2d(2,2)
        
        # Exercise: Add a recurrent unit like and RNN or GRU
        # >> YOUR CODE HERE <<
        self.rnn_1 = nn.RNN(input_size = 40*40*10,
                            hidden_size = 192,
                            num_layers = 2,
                            batch_first = True)
        
        self.l_out = Linear(in_features=features_cat_size,
                            out_features=NUM_CLASSES,
                            bias=False)
        
    def forward(self, x_img, x_margin, x_shape, x_texture):
        features = []
        out = {}
        
        ## Convolutional layer ##
        # - Change dimensions to fit the convolutional layer 
        # - Apply Conv2d
        # - Use an activation function
        # - Change dimensions s.t. the features can be used in the final FFNN output layer
        
        # >> YOUR CODE HERE <<
        
        x_img = self.pool(F.relu(self.conv_1(x_img))
        x_img = self.l_out(x_img)
        
        # Append features to the list "features"
        features.append(features_img)
        
        
        ## Use concatenated leaf features for FFNN ##
        x = torch.cat((x_margin, x_texture), dim=1)  # if you want to use features as feature vectors
        features_vector = x
        features.append(features_vector)
        
        
        ## Use concatenated leaf features for RNN ##
        # - Chage dimensions to fit GRU
        # - Apply GRU
        # - Change dimensions s.t. the features can be used in the final FFNN output layer

        # >> YOUR CODE HERE <<
        
        # Append features to the list "features"
        features.append(features_rnn)
        
        
        ## Output layer where all features are in use ##
        features_final = torch.cat(features, dim=1)
        
        out['out'] = self.l_out(features_final) 
        return out

net = Net()
if use_cuda:
    net.cuda()
print(net)
# Out:
#   File "<ipython-input-215-78255dcb53a7>", line 49
#     x_img = self.l_out(x_img)
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Build the cost function

# %% [markdown]
# ## Exercise 8
# 8.1) Since this is a classification task we will use the cross-entropy loss. Define the cross-entropy loss as the loss function in the code below.

# %%
LEARNING_RATE = 0.001
criterion = nn.CrossEntropyLoss()          #<-- Your code here.   

# weight_decay is equal to L2 regularization
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)

def accuracy(ys, ts):
    predictions = torch.max(ys, 1)[1]
    correct_prediction = torch.eq(predictions, ts)
    return torch.mean(correct_prediction.float())

# %% [markdown]
# ## Test network
#
# #### Debugging
# The following cell might cause you some errors - try these suggestions before you try anyting else.
#
# * **Your kernel keeps dying** on the line below it is most likely because you run out of memory.
# The two most likely solutions are
#  1. reduce the image size further
#  1. change your network architecture such that it uses less resources
#
# * **`RuntimeError: size mismatch, m1: [??? x ???], m2: [??? x ???]`**
#  1. `features_cat_size` must match the actual output of the network i.e. the second dimension in `m1`.
#
# * **Training is very slow**. This is most likely caused by the images.
#  1. Try and reduce the size of the images further, or reduce the dimensions of the network using either pooling or strides.

# %%
_img_shape = tuple([batch_size] + list(IMAGE_SHAPE))
_feature_shape = (batch_size, NUM_FEATURES)

def randnorm(size):
    return np.random.normal(0, 1, size).astype('float32')

# dummy data
_x_image = get_variable(Variable(torch.from_numpy(randnorm(_img_shape))))
_x_margin = get_variable(Variable(torch.from_numpy(randnorm(_feature_shape))))
_x_shape = get_variable(Variable(torch.from_numpy(randnorm(_feature_shape))))
_x_texture = get_variable(Variable(torch.from_numpy(randnorm(_feature_shape))))

# test the forward pass
output = net(x_img=_x_image, x_margin=_x_margin, x_shape=_x_shape, x_texture=_x_texture)
output['out']

# %% [markdown]
# # Train

# %%
# Setup settings for training 
VALIDATION_SIZE = 0.1 # 0.1 is ~ 100 samples for validation
max_iter = 1000
log_every = 100
eval_every = 100

# Function to get label
def get_labels(batch):
    return get_variable(Variable(torch.from_numpy(batch['ts']).long()))

# Function to get input
def get_input(batch):
    return {
        'x_img': get_variable(Variable(torch.from_numpy(batch['images']))),
        'x_margin': get_variable(Variable(torch.from_numpy(batch['margins']))),
        'x_shape': get_variable(Variable(torch.from_numpy(batch['shapes']))),
        'x_texture': get_variable(Variable(torch.from_numpy(batch['textures'])))
    }

# Initialize lists for training and validation
train_iter = []
train_loss, train_accs = [], []
valid_iter = []
valid_loss, valid_accs = [], []

# Generate batches
batch_gen = data_utils.batch_generator(data,
                                       batch_size=batch_size,
                                       num_classes=NUM_CLASSES,
                                       num_iterations=max_iter,
                                       seed=42,
                                       val_size=VALIDATION_SIZE)

# Train network
net.train()
for i, batch_train in enumerate(batch_gen.gen_train()):
    if i % eval_every == 0:
        
        # Do the validaiton
        net.eval()
        val_losses, val_accs, val_lengths = 0, 0, 0
        for batch_valid, num in batch_gen.gen_valid():
            output = net(**get_input(batch_valid))
            labels_argmax = torch.max(get_labels(batch_valid), 1)[1]
            val_losses += criterion(output['out'], labels_argmax) * num
            val_accs += accuracy(output['out'], labels_argmax) * num
            val_lengths += num

        # Divide by the total accumulated batch sizes
        val_losses /= val_lengths
        val_accs /= val_lengths
        valid_loss.append(get_numpy(val_losses))
        valid_accs.append(get_numpy(val_accs))
        valid_iter.append(i)
#         print("Valid, it: {} loss: {:.2f} accs: {:.2f}\n".format(i, valid_loss[-1], valid_accs[-1]))
        net.train()
    
    # Train network
    output = net(**get_input(batch_train))
    labels_argmax = torch.max(get_labels(batch_train), 1)[1]
    batch_loss = criterion(output['out'], labels_argmax)
    
    train_iter.append(i)
    train_loss.append(float(get_numpy(batch_loss)))
    train_accs.append(float(get_numpy(accuracy(output['out'], labels_argmax))))
    
    optimizer.zero_grad()
    batch_loss.backward()
    optimizer.step()
    
    # Log i figure
    if i % log_every == 0:
        fig = plt.figure(figsize=(12,4))
        plt.subplot(1, 2, 1)
        plt.plot(train_iter, train_loss, label='train_loss')
        plt.plot(valid_iter, valid_loss, label='valid_loss')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(train_iter, train_accs, label='train_accs')
        plt.plot(valid_iter, valid_accs, label='valid_accs')
        plt.legend()
        plt.show()
        clear_output(wait=True)
#         print("Train, it: {} loss: {:.2f} accs: {:.2f}".format(i, train_loss[-1], train_accs[-1]))
        
    if max_iter < i:
        break

# %% [markdown]
# ## Exercise 9
#
# **Tip** This is very small dataset (number of observations) compared to the number of features.
# This means that overfitting will likely be an issue, and sometimes fancy tricks won't do any good.
# Keep that in mind, and always start out simple.
#
# **3.1) Improve the network**, and get as high a validation score as you can.
# When trying to improve the network nothing is sacred, you can change learning rate, try testing various learning rates, batch sizes, validation sizes, etc.
# And most importantly, the validation set is very small (only 1 sample per class), etc.
#
# To get you of to a good start we have created a list of **things you might want to try**:
# * Add more layers (mostly fully connected and convolutional)
# * Increase or decrease the batch size
# * Use dropout (a lot - e.g. between the convolutional layers)
# * Use batchnormalization (a lot)
# * Try with L2 regularization (weight decay)
# * Use only the image for training (with CNN) - comment on the increased time between iterations.
# * Change the image size to be bigger or smaller
# * Try other combinations of FFN, CNN, RNN parts in various ways (bigger is not always better)
#
# If your network is not performing as well as you would like it to, [here](http://theorangeduck.com/page/neural-network-not-working) is a great explanation of what might have gone wrong.
#
#
# **3.2) Improve Kaggle score**. Once happy try to get the best score on Kaggle for this dataset as you can (**upload** instructions below)
# You can upload your solution multiple times as you progress.
# A very good implementation would get a score between $0.04$ to $0.06$ (the smaller the better), try and see if you can get there, and explain what might have gone wrong if you cant.
#
#
# **3.3) Reflect on the process**, and how you got to your final design and discuss your final results.
# What worked, and what didn't?
# Include at least the following:
# * Description of final architecture
# * Description of training parameters
# * Description of final results (Kaggle and validation)
#
# **Answer:**

# %% [markdown]
# # Submission to Kaggle
#
# First we have to make testset predictions, then we have to place it in the submission file and the upload to Kaggle for our score! You can upload at max 5 submissions a day.

# %%
# GET PREDICTIONS
# containers to collect ids and predictions
ids_test, preds_test = [], []
net.eval()
# run like with validation
for batch_test, num in batch_gen.gen_test():
    output = net(**get_input(batch_test))
    y_out = output['out'].data

    ids_test += batch_test['ids']
    if num!=len(y_out):
        # in case of the last batch, num will be less than batch_size
        y_out = y_out[:num]
    preds_test.append(y_out)
preds_test = np.concatenate(preds_test, axis=0)
assert len(ids_test) == len(preds_test)

# %% [markdown]
# ## Make submission file

# %%
preds_df = pd.DataFrame(preds_test, columns=data.le.classes_)
ids_test_df = pd.DataFrame(ids_test, columns=["id"])
submission = pd.concat([ids_test_df, preds_df], axis=1)
submission.to_csv(drive_path + 'submission.csv', index=False)

# below prints the submission, can be removed and replaced with code block below
submission.head(5)

# %% [markdown]
# ## Upload submission
#
# 1. Go to [`https://www.kaggle.com/c/leaf-classification/submit`](https://www.kaggle.com/c/leaf-classification/submit)
# 3. Click or drop your submission here (writing a description is good practice)
# 4. Submit and look at where you are on the leaderboard.
#
# Success!
